# %% [markdown]
# Notebook to load the result.json from a random search / grid search hyperparameter selection section

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import json
from pathlib import Path
import sys
import os
import re

sys.path.append('../')
from eval_metrics import METRICS

# %%
run_name = 'lda_multicore_random_search_20240119_114453'
run_dir = Path(run_name)
run_result_json_path = run_dir.joinpath('result.json')
run_config_json_path = run_dir.joinpath('config.json')

metrics_names = [m.value for m in METRICS]

# %%
with open(run_result_json_path) as f:
    run_result = json.load(f)

with open(run_config_json_path) as f:
    run_config = json.load(f)

run_result
# Out:
# {'best_metric': -0.03381356620954536,
#  'best_model_checkpoint': 'lda_multicore_random_search_20240119_114453/lda_multicore_offset_16_num_topics_10_decay_0.7',
#  'best_hyperparameters': {'num_topics': 30,
#   'workers': 3,
#   'chunksize': 2000,
#   'passes': 10,
#   'alpha': 'symmetric',
#   'eta': None,
#   'decay': 0.9,
#   'offset': 16,
#   'eval_every': 10,
#   'iterations': 50,
#   'gamma_threshold': 0.001,
#   'minimum_probability': 0.01,
#   'random_state': 42,
#   'minimum_phi_value': 0.01,
#   'per_word_topics': False,
#   'dtype': "<class 'numpy.float32'>"},
#  'monitor_type': 'c_npmi',
#  'log_history': [{'c_npmi': -0.14408378239825823,
#    'c_v': 0.4467070662402987,
#    'u_mass': -12.384271956401005,
#    'c_uci': -4.9745392889314894,
#    'topic_diversity': 0.8933333333333333,
#    'inverted_rbo': 0.9587820470646962,
#    'pairwise_jaccard_similarity': 0.029854809437386474,
#    'hyperparameters': {'num_topics': 30,
#     'workers': 3,
#     'chunksize': 2000,
#     'passes': 10,
#     'alpha': 'symmetric',
#     'eta': None,
#     'decay': 0.7,
#     'offset': 128,
#     'eval_every': 10,
#     'iterations': 50,
#     'gamma_threshold': 0.001,
#     'minimum_probability': 0.01,
#     'random_state': 42,
#     'minimum_phi_value': 0.01,
#     'per_word_topics': False,
#     'dtype': "<class 'numpy.float32'>"}},
#   {'c_npmi': -0.12066801423313349,
#    'c_v': 0.4695268507787126,
#    'u_mass': -10.097817853049417,
#    'c_uci': -4.300027629612048,
#    'topic_diversity': 0.835,
#    'inverted_rbo': 0.9462048619129699,
#    'pairwise_jaccard_similarity': 0.03728160701030176,
#    'hyperparameters': {'num_topics': 20,
#     'workers': 3,
#     'chunksize': 2000,
#     'passes': 10,
#     'alpha': 'symmetric',
#     'eta': None,
#     'decay': 0.8,
#     'offset': 64,
#     'eval_every': 10,
#     'iterations': 50,
#     'gamma_threshold': 0.001,
#     'minimum_probability': 0.01,
#     'random_state': 42,
#     'minimum_phi_value': 0.01,
#     'per_word_topics': False,
#     'dtype': "<class 'numpy.float32'>"}},
#   {'c_npmi': -0.05030281471529237,
#    'c_v': 0.5343619089383287,
#    'u_mass': -6.049481500333536,
#    'c_uci': -2.594367468508137,
#    'topic_diversity': 0.78,
#    'inverted_rbo': 0.8858616367277777,
#    'pairwise_jaccard_similarity': 0.05694683331422236,
#    'hyperparameters': {'num_topics': 10,
#     'workers': 3,
#     'chunksize': 2000,
#     'passes': 10,
#     'alpha': 'symmetric',
#     'eta': None,
#     'decay': 0.8,
#     'offset': 16,
#     'eval_every': 10,
#     'iterations': 50,
#     'gamma_threshold': 0.001,
#     'minimum_probability': 0.01,
#     'random_state': 42,
#     'minimum_phi_value': 0.01,
#     'per_word_topics': False,
#     'dtype': "<class 'numpy.float32'>"}},
#   {'c_npmi': -0.09981806421446113,
#    'c_v': 0.45665500093052236,
#    'u_mass': -7.652753554926018,
#    'c_uci': -3.448682941393563,
#    'topic_diversity': 0.76,
#    'inverted_rbo': 0.921964383407782,
#    'pairwise_jaccard_similarity': 0.05112161207973486,
#    'hyperparameters': {'num_topics': 20,
#     'workers': 3,
#     'chunksize': 2000,
#     'passes': 10,
#     'alpha': 'symmetric',
#     'eta': None,
#     'decay': 0.9,
#     'offset': 16,
#     'eval_every': 10,
#     'iterations': 50,
#     'gamma_threshold': 0.001,
#     'minimum_probability': 0.01,
#     'random_state': 42,
#     'minimum_phi_value': 0.01,
#     'per_word_topics': False,
#     'dtype': "<class 'numpy.float32'>"}},
#   {'c_npmi': -0.03381356620954536,
#    'c_v': 0.5578107736258711,
#    'u_mass': -5.359240812979768,
#    'c_uci': -2.179838416345453,
#    'topic_diversity': 0.79,
#    'inverted_rbo': 0.9052212120423809,
#    'pairwise_jaccard_similarity': 0.04896418606428926,
#    'hyperparameters': {'num_topics': 10,
#     'workers': 3,
#     'chunksize': 2000,
#     'passes': 10,
#     'alpha': 'symmetric',
#     'eta': None,
#     'decay': 0.7,
#     'offset': 16,
#     'eval_every': 10,
#     'iterations': 50,
#     'gamma_threshold': 0.001,
#     'minimum_probability': 0.01,
#     'random_state': 42,
#     'minimum_phi_value': 0.01,
#     'per_word_topics': False,
#     'dtype': "<class 'numpy.float32'>"}},
#   {'c_npmi': -0.07749107690817003,
#    'c_v': 0.46324679409980085,
#    'u_mass': -6.11092818420388,
#    'c_uci': -2.8706903072331293,
#    'topic_diversity': 0.74,
#    'inverted_rbo': 0.8939976446777778,
#    'pairwise_jaccard_similarity': 0.08530831435888198,
#    'hyperparameters': {'num_topics': 10,
#     'workers': 3,
#     'chunksize': 2000,
#     'passes': 10,
#     'alpha': 'symmetric',
#     'eta': None,
#     'decay': 0.8,
#     'offset': 128,
#     'eval_every': 10,
#     'iterations': 50,
#     'gamma_threshold': 0.001,
#     'minimum_probability': 0.01,
#     'random_state': 42,
#     'minimum_phi_value': 0.01,
#     'per_word_topics': False,
#     'dtype': "<class 'numpy.float32'>"}},
#   {'c_npmi': -0.14146988283296127,
#    'c_v': 0.4174235716834188,
#    'u_mass': -10.89011557436142,
#    'c_uci': -4.769388598946754,
#    'topic_diversity': 0.8166666666666667,
#    'inverted_rbo': 0.924800694104926,
#    'pairwise_jaccard_similarity': 0.050146495379761236,
#    'hyperparameters': {'num_topics': 30,
#     'workers': 3,
#     'chunksize': 2000,
#     'passes': 10,
#     'alpha': 'symmetric',
#     'eta': None,
#     'decay': 0.8,
#     'offset': 64,
#     'eval_every': 10,
#     'iterations': 50,
#     'gamma_threshold': 0.001,
#     'minimum_probability': 0.01,
#     'random_state': 42,
#     'minimum_phi_value': 0.01,
#     'per_word_topics': False,
#     'dtype': "<class 'numpy.float32'>"}},
#   {'c_npmi': -0.12221297267062234,
#    'c_v': 0.372327297626618,
#    'u_mass': -7.868889188581379,
#    'c_uci': -3.975141456422636,
#    'topic_diversity': 0.6066666666666667,
#    'inverted_rbo': 0.806936367997849,
#    'pairwise_jaccard_similarity': 0.1213929855063631,
#    'hyperparameters': {'num_topics': 30,
#     'workers': 3,
#     'chunksize': 2000,
#     'passes': 10,
#     'alpha': 'symmetric',
#     'eta': None,
#     'decay': 0.8,
#     'offset': 128,
#     'eval_every': 10,
#     'iterations': 50,
#     'gamma_threshold': 0.001,
#     'minimum_probability': 0.01,
#     'random_state': 42,
#     'minimum_phi_value': 0.01,
#     'per_word_topics': False,
#     'dtype': "<class 'numpy.float32'>"}},
#   {'c_npmi': -0.1294207631975694,
#    'c_v': 0.5219103017968774,
#    'u_mass': -8.912569379195483,
#    'c_uci': -4.325420066900912,
#    'topic_diversity': 0.83,
#    'inverted_rbo': 0.9466577370628947,
#    'pairwise_jaccard_similarity': 0.03687062082450704,
#    'hyperparameters': {'num_topics': 20,
#     'workers': 3,
#     'chunksize': 2000,
#     'passes': 10,
#     'alpha': 'symmetric',
#     'eta': None,
#     'decay': 0.8,
#     'offset': 16,
#     'eval_every': 10,
#     'iterations': 50,
#     'gamma_threshold': 0.001,
#     'minimum_probability': 0.01,
#     'random_state': 42,
#     'minimum_phi_value': 0.01,
#     'per_word_topics': False,
#     'dtype': "<class 'numpy.float32'>"}},
#   {'c_npmi': -0.14597859440191793,
#    'c_v': 0.44966003974963215,
#    'u_mass': -10.800260844583127,
#    'c_uci': -4.811866436040522,
#    'topic_diversity': 0.8366666666666667,
#    'inverted_rbo': 0.9310395938621675,
#    'pairwise_jaccard_similarity': 0.043879616779157735,
#    'hyperparameters': {'num_topics': 30,
#     'workers': 3,
#     'chunksize': 2000,
#     'passes': 10,
#     'alpha': 'symmetric',
#     'eta': None,
#     'decay': 0.9,
#     'offset': 16,
#     'eval_every': 10,
#     'iterations': 50,
#     'gamma_threshold': 0.001,
#     'minimum_probability': 0.01,
#     'random_state': 42,
#     'minimum_phi_value': 0.01,
#     'per_word_topics': False,
#     'dtype': "<class 'numpy.float32'>"}}]}

# %%
# focus on the log history
# create a dataframe from the log history

log_history = run_result['log_history']

# from: https://www.freecodecamp.org/news/how-to-flatten-a-dictionary-in-python-in-4-different-ways/
from collections.abc import MutableMapping

def _flatten_dict_gen(d, parent_key, sep):
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, MutableMapping):
            yield from flatten_dict(v, new_key, sep=sep).items()
        else:
            yield new_key, v


def flatten_dict(d: MutableMapping, parent_key: str = '', sep: str = '.'):
    return dict(_flatten_dict_gen(d, parent_key, sep))

# for each dictionary in the log_history list
# convert them to a flattened dictionary
# then append to a list
log_history_flattened = [flatten_dict(log, sep='.') for log in log_history]
log_history_flattened
# Out:
# [{'c_npmi': -0.14408378239825823,
#   'c_v': 0.4467070662402987,
#   'u_mass': -12.384271956401005,
#   'c_uci': -4.9745392889314894,
#   'topic_diversity': 0.8933333333333333,
#   'inverted_rbo': 0.9587820470646962,
#   'pairwise_jaccard_similarity': 0.029854809437386474,
#   'hyperparameters.num_topics': 30,
#   'hyperparameters.workers': 3,
#   'hyperparameters.chunksize': 2000,
#   'hyperparameters.passes': 10,
#   'hyperparameters.alpha': 'symmetric',
#   'hyperparameters.eta': None,
#   'hyperparameters.decay': 0.7,
#   'hyperparameters.offset': 128,
#   'hyperparameters.eval_every': 10,
#   'hyperparameters.iterations': 50,
#   'hyperparameters.gamma_threshold': 0.001,
#   'hyperparameters.minimum_probability': 0.01,
#   'hyperparameters.random_state': 42,
#   'hyperparameters.minimum_phi_value': 0.01,
#   'hyperparameters.per_word_topics': False,
#   'hyperparameters.dtype': "<class 'numpy.float32'>"},
#  {'c_npmi': -0.12066801423313349,
#   'c_v': 0.4695268507787126,
#   'u_mass': -10.097817853049417,
#   'c_uci': -4.300027629612048,
#   'topic_diversity': 0.835,
#   'inverted_rbo': 0.9462048619129699,
#   'pairwise_jaccard_similarity': 0.03728160701030176,
#   'hyperparameters.num_topics': 20,
#   'hyperparameters.workers': 3,
#   'hyperparameters.chunksize': 2000,
#   'hyperparameters.passes': 10,
#   'hyperparameters.alpha': 'symmetric',
#   'hyperparameters.eta': None,
#   'hyperparameters.decay': 0.8,
#   'hyperparameters.offset': 64,
#   'hyperparameters.eval_every': 10,
#   'hyperparameters.iterations': 50,
#   'hyperparameters.gamma_threshold': 0.001,
#   'hyperparameters.minimum_probability': 0.01,
#   'hyperparameters.random_state': 42,
#   'hyperparameters.minimum_phi_value': 0.01,
#   'hyperparameters.per_word_topics': False,
#   'hyperparameters.dtype': "<class 'numpy.float32'>"},
#  {'c_npmi': -0.05030281471529237,
#   'c_v': 0.5343619089383287,
#   'u_mass': -6.049481500333536,
#   'c_uci': -2.594367468508137,
#   'topic_diversity': 0.78,
#   'inverted_rbo': 0.8858616367277777,
#   'pairwise_jaccard_similarity': 0.05694683331422236,
#   'hyperparameters.num_topics': 10,
#   'hyperparameters.workers': 3,
#   'hyperparameters.chunksize': 2000,
#   'hyperparameters.passes': 10,
#   'hyperparameters.alpha': 'symmetric',
#   'hyperparameters.eta': None,
#   'hyperparameters.decay': 0.8,
#   'hyperparameters.offset': 16,
#   'hyperparameters.eval_every': 10,
#   'hyperparameters.iterations': 50,
#   'hyperparameters.gamma_threshold': 0.001,
#   'hyperparameters.minimum_probability': 0.01,
#   'hyperparameters.random_state': 42,
#   'hyperparameters.minimum_phi_value': 0.01,
#   'hyperparameters.per_word_topics': False,
#   'hyperparameters.dtype': "<class 'numpy.float32'>"},
#  {'c_npmi': -0.09981806421446113,
#   'c_v': 0.45665500093052236,
#   'u_mass': -7.652753554926018,
#   'c_uci': -3.448682941393563,
#   'topic_diversity': 0.76,
#   'inverted_rbo': 0.921964383407782,
#   'pairwise_jaccard_similarity': 0.05112161207973486,
#   'hyperparameters.num_topics': 20,
#   'hyperparameters.workers': 3,
#   'hyperparameters.chunksize': 2000,
#   'hyperparameters.passes': 10,
#   'hyperparameters.alpha': 'symmetric',
#   'hyperparameters.eta': None,
#   'hyperparameters.decay': 0.9,
#   'hyperparameters.offset': 16,
#   'hyperparameters.eval_every': 10,
#   'hyperparameters.iterations': 50,
#   'hyperparameters.gamma_threshold': 0.001,
#   'hyperparameters.minimum_probability': 0.01,
#   'hyperparameters.random_state': 42,
#   'hyperparameters.minimum_phi_value': 0.01,
#   'hyperparameters.per_word_topics': False,
#   'hyperparameters.dtype': "<class 'numpy.float32'>"},
#  {'c_npmi': -0.03381356620954536,
#   'c_v': 0.5578107736258711,
#   'u_mass': -5.359240812979768,
#   'c_uci': -2.179838416345453,
#   'topic_diversity': 0.79,
#   'inverted_rbo': 0.9052212120423809,
#   'pairwise_jaccard_similarity': 0.04896418606428926,
#   'hyperparameters.num_topics': 10,
#   'hyperparameters.workers': 3,
#   'hyperparameters.chunksize': 2000,
#   'hyperparameters.passes': 10,
#   'hyperparameters.alpha': 'symmetric',
#   'hyperparameters.eta': None,
#   'hyperparameters.decay': 0.7,
#   'hyperparameters.offset': 16,
#   'hyperparameters.eval_every': 10,
#   'hyperparameters.iterations': 50,
#   'hyperparameters.gamma_threshold': 0.001,
#   'hyperparameters.minimum_probability': 0.01,
#   'hyperparameters.random_state': 42,
#   'hyperparameters.minimum_phi_value': 0.01,
#   'hyperparameters.per_word_topics': False,
#   'hyperparameters.dtype': "<class 'numpy.float32'>"},
#  {'c_npmi': -0.07749107690817003,
#   'c_v': 0.46324679409980085,
#   'u_mass': -6.11092818420388,
#   'c_uci': -2.8706903072331293,
#   'topic_diversity': 0.74,
#   'inverted_rbo': 0.8939976446777778,
#   'pairwise_jaccard_similarity': 0.08530831435888198,
#   'hyperparameters.num_topics': 10,
#   'hyperparameters.workers': 3,
#   'hyperparameters.chunksize': 2000,
#   'hyperparameters.passes': 10,
#   'hyperparameters.alpha': 'symmetric',
#   'hyperparameters.eta': None,
#   'hyperparameters.decay': 0.8,
#   'hyperparameters.offset': 128,
#   'hyperparameters.eval_every': 10,
#   'hyperparameters.iterations': 50,
#   'hyperparameters.gamma_threshold': 0.001,
#   'hyperparameters.minimum_probability': 0.01,
#   'hyperparameters.random_state': 42,
#   'hyperparameters.minimum_phi_value': 0.01,
#   'hyperparameters.per_word_topics': False,
#   'hyperparameters.dtype': "<class 'numpy.float32'>"},
#  {'c_npmi': -0.14146988283296127,
#   'c_v': 0.4174235716834188,
#   'u_mass': -10.89011557436142,
#   'c_uci': -4.769388598946754,
#   'topic_diversity': 0.8166666666666667,
#   'inverted_rbo': 0.924800694104926,
#   'pairwise_jaccard_similarity': 0.050146495379761236,
#   'hyperparameters.num_topics': 30,
#   'hyperparameters.workers': 3,
#   'hyperparameters.chunksize': 2000,
#   'hyperparameters.passes': 10,
#   'hyperparameters.alpha': 'symmetric',
#   'hyperparameters.eta': None,
#   'hyperparameters.decay': 0.8,
#   'hyperparameters.offset': 64,
#   'hyperparameters.eval_every': 10,
#   'hyperparameters.iterations': 50,
#   'hyperparameters.gamma_threshold': 0.001,
#   'hyperparameters.minimum_probability': 0.01,
#   'hyperparameters.random_state': 42,
#   'hyperparameters.minimum_phi_value': 0.01,
#   'hyperparameters.per_word_topics': False,
#   'hyperparameters.dtype': "<class 'numpy.float32'>"},
#  {'c_npmi': -0.12221297267062234,
#   'c_v': 0.372327297626618,
#   'u_mass': -7.868889188581379,
#   'c_uci': -3.975141456422636,
#   'topic_diversity': 0.6066666666666667,
#   'inverted_rbo': 0.806936367997849,
#   'pairwise_jaccard_similarity': 0.1213929855063631,
#   'hyperparameters.num_topics': 30,
#   'hyperparameters.workers': 3,
#   'hyperparameters.chunksize': 2000,
#   'hyperparameters.passes': 10,
#   'hyperparameters.alpha': 'symmetric',
#   'hyperparameters.eta': None,
#   'hyperparameters.decay': 0.8,
#   'hyperparameters.offset': 128,
#   'hyperparameters.eval_every': 10,
#   'hyperparameters.iterations': 50,
#   'hyperparameters.gamma_threshold': 0.001,
#   'hyperparameters.minimum_probability': 0.01,
#   'hyperparameters.random_state': 42,
#   'hyperparameters.minimum_phi_value': 0.01,
#   'hyperparameters.per_word_topics': False,
#   'hyperparameters.dtype': "<class 'numpy.float32'>"},
#  {'c_npmi': -0.1294207631975694,
#   'c_v': 0.5219103017968774,
#   'u_mass': -8.912569379195483,
#   'c_uci': -4.325420066900912,
#   'topic_diversity': 0.83,
#   'inverted_rbo': 0.9466577370628947,
#   'pairwise_jaccard_similarity': 0.03687062082450704,
#   'hyperparameters.num_topics': 20,
#   'hyperparameters.workers': 3,
#   'hyperparameters.chunksize': 2000,
#   'hyperparameters.passes': 10,
#   'hyperparameters.alpha': 'symmetric',
#   'hyperparameters.eta': None,
#   'hyperparameters.decay': 0.8,
#   'hyperparameters.offset': 16,
#   'hyperparameters.eval_every': 10,
#   'hyperparameters.iterations': 50,
#   'hyperparameters.gamma_threshold': 0.001,
#   'hyperparameters.minimum_probability': 0.01,
#   'hyperparameters.random_state': 42,
#   'hyperparameters.minimum_phi_value': 0.01,
#   'hyperparameters.per_word_topics': False,
#   'hyperparameters.dtype': "<class 'numpy.float32'>"},
#  {'c_npmi': -0.14597859440191793,
#   'c_v': 0.44966003974963215,
#   'u_mass': -10.800260844583127,
#   'c_uci': -4.811866436040522,
#   'topic_diversity': 0.8366666666666667,
#   'inverted_rbo': 0.9310395938621675,
#   'pairwise_jaccard_similarity': 0.043879616779157735,
#   'hyperparameters.num_topics': 30,
#   'hyperparameters.workers': 3,
#   'hyperparameters.chunksize': 2000,
#   'hyperparameters.passes': 10,
#   'hyperparameters.alpha': 'symmetric',
#   'hyperparameters.eta': None,
#   'hyperparameters.decay': 0.9,
#   'hyperparameters.offset': 16,
#   'hyperparameters.eval_every': 10,
#   'hyperparameters.iterations': 50,
#   'hyperparameters.gamma_threshold': 0.001,
#   'hyperparameters.minimum_probability': 0.01,
#   'hyperparameters.random_state': 42,
#   'hyperparameters.minimum_phi_value': 0.01,
#   'hyperparameters.per_word_topics': False,
#   'hyperparameters.dtype': "<class 'numpy.float32'>"}]

# %%
# create a dataframe from the list of flattened dictionaries
log_history_df = pd.DataFrame(log_history_flattened)
log_history_df
# Out:
#      c_npmi       c_v     u_mass     c_uci  topic_diversity  inverted_rbo  \
# 0 -0.144084  0.446707 -12.384272 -4.974539         0.893333      0.958782
# 1 -0.120668  0.469527 -10.097818 -4.300028         0.835000      0.946205
# 2 -0.050303  0.534362  -6.049482 -2.594367         0.780000      0.885862
# 3 -0.099818  0.456655  -7.652754 -3.448683         0.760000      0.921964
# 4 -0.033814  0.557811  -5.359241 -2.179838         0.790000      0.905221
# 5 -0.077491  0.463247  -6.110928 -2.870690         0.740000      0.893998
# 6 -0.141470  0.417424 -10.890116 -4.769389         0.816667      0.924801
# 7 -0.122213  0.372327  -7.868889 -3.975141         0.606667      0.806936
# 8 -0.129421  0.521910  -8.912569 -4.325420         0.830000      0.946658
# 9 -0.145979  0.449660 -10.800261 -4.811866         0.836667      0.931040
#
#    pairwise_jaccard_similarity  hyperparameters.num_topics  \
# 0                     0.029855                          30
# 1                     0.037282                          20
# 2                     0.056947                          10
# 3                     0.051122                          20
# 4                     0.048964                          10
# 5                     0.085308                          10
# 6                     0.050146                          30
# 7                     0.121393                          30
# 8                     0.036871                          20
# 9                     0.043880                          30
#
#    hyperparameters.workers  hyperparameters.chunksize  ...  \
# 0                        3                       2000  ...
# 1                        3                       2000  ...
# 2                        3                       2000  ...
# 3                        3                       2000  ...
# 4                        3                       2000  ...
# 5                        3                       2000  ...
# 6                        3                       2000  ...
# 7                        3                       2000  ...
# 8                        3                       2000  ...
# 9                        3                       2000  ...
#
#    hyperparameters.decay hyperparameters.offset hyperparameters.eval_every  \
# 0                    0.7                    128                         10
# 1                    0.8                     64                         10
# 2                    0.8                     16                         10
# 3                    0.9                     16                         10
# 4                    0.7                     16                         10
# 5                    0.8                    128                         10
# 6                    0.8                     64                         10
# 7                    0.8                    128                         10
# 8                    0.8                     16                         10
# 9                    0.9                     16                         10
#
#    hyperparameters.iterations  hyperparameters.gamma_threshold  \
# 0                          50                            0.001
# 1                          50                            0.001
# 2                          50                            0.001
# 3                          50                            0.001
# 4                          50                            0.001
# 5                          50                            0.001
# 6                          50                            0.001
# 7                          50                            0.001
# 8                          50                            0.001
# 9                          50                            0.001
#
#    hyperparameters.minimum_probability  hyperparameters.random_state  \
# 0                                 0.01                            42
# 1                                 0.01                            42
# 2                                 0.01                            42
# 3                                 0.01                            42
# 4                                 0.01                            42
# 5                                 0.01                            42
# 6                                 0.01                            42
# 7                                 0.01                            42
# 8                                 0.01                            42
# 9                                 0.01                            42
#
#    hyperparameters.minimum_phi_value  hyperparameters.per_word_topics  \
# 0                               0.01                            False
# 1                               0.01                            False
# 2                               0.01                            False
# 3                               0.01                            False
# 4                               0.01                            False
# 5                               0.01                            False
# 6                               0.01                            False
# 7                               0.01                            False
# 8                               0.01                            False
# 9                               0.01                            False
#
#      hyperparameters.dtype
# 0  <class 'numpy.float32'>
# 1  <class 'numpy.float32'>
# 2  <class 'numpy.float32'>
# 3  <class 'numpy.float32'>
# 4  <class 'numpy.float32'>
# 5  <class 'numpy.float32'>
# 6  <class 'numpy.float32'>
# 7  <class 'numpy.float32'>
# 8  <class 'numpy.float32'>
# 9  <class 'numpy.float32'>
#
# [10 rows x 23 columns]

# %%
# sort by c_npmi
aaa = log_history_df.sort_values(by='c_npmi', ascending=False)
aaa
# Out:
#       c_npmi       c_v    u_mass     c_uci  topic_diversity  inverted_rbo  \
# 11  0.159360  0.736042 -0.215378  1.572884         0.680000      0.971925
# 17  0.148927  0.714929 -0.218321  1.494394         0.678750      0.976178
# 15  0.143404  0.704631 -0.222557  1.398259         0.688000      0.968158
# 4   0.137412  0.713508 -0.226645  1.238540         0.718421      0.961122
# 2   0.132052  0.719587 -0.083229  1.092262         0.660000      0.886554
# 1   0.111151  0.744181 -0.152728  0.891481         0.605085      0.945372
# 10  0.110444  0.719416 -0.227431  0.941981         0.680769      0.977346
# 16  0.101151  0.724493 -0.216620  0.738231         0.640000      0.946919
# 9   0.100998  0.761304 -0.160130  0.824367         0.674359      0.971981
# 23  0.100161  0.719013 -0.165695  0.755407         0.636735      0.953011
# 7   0.099775  0.740856 -0.177363  0.686020         0.575862      0.913845
# 22  0.092475  0.629878 -0.465147  0.468985         0.840000      0.984671
# 0   0.092217  0.753588 -0.150548  0.645419         0.606250      0.951025
# 5   0.091976  0.753699 -0.143123  0.690079         0.657303      0.976477
# 20  0.091074  0.745403 -0.152650  0.678093         0.668116      0.968834
# 14  0.091014  0.689310 -0.278926  0.604335         0.723596      0.983895
# 13  0.088310  0.686396 -0.326609  0.553766         0.704082      0.984155
# 8   0.078202  0.709542 -0.189626  0.435725         0.702899      0.978370
# 21  0.077460  0.698135 -0.188907  0.424796         0.713333      0.970008
# 19  0.076788  0.702512 -0.255096  0.427047         0.690909      0.979583
# 6   0.071857  0.700117 -0.217763  0.289676         0.750000      0.983080
# 3   0.071528  0.648377 -0.303749  0.202981         0.768571      0.987691
# 12  0.061402  0.637311 -0.297421 -0.012197         0.780000      0.977916
# 18  0.057235  0.624205 -0.201727 -0.263578         0.910000      0.982728
#
#     pairwise_jaccard_similarity  \
# 11                     0.029161
# 17                     0.023130
# 15                     0.027177
# 4                      0.035787
# 2                      0.113510
# 1                      0.060758
# 10                     0.024298
# 16                     0.055351
# 9                      0.031359
# 23                     0.048740
# 7                      0.091492
# 22                     0.013068
# 0                      0.053354
# 5                      0.025502
# 20                     0.033474
# 14                     0.015741
# 13                     0.015548
# 8                      0.019305
# 21                     0.026830
# 19                     0.021892
# 6                      0.016910
# 3                      0.011415
# 12                     0.020359
# 18                     0.013125
#
#                                            model_name  \
# 11  sb_model_name_or_path_all-mpnet-base-v1_hs_min...
# 17  sb_model_name_or_path_all-mpnet-base-v1_hs_min...
# 15  sb_model_name_or_path_all-mpnet-base-v1_hs_min...
# 4   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 2   sb_model_name_or_path_all-mpnet-base-v1_hs_min...
# 1   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 10  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 16  sb_model_name_or_path_all-mpnet-base-v1_hs_min...
# 9   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 23  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 7   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 22  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 0   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 5   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 20  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 14  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 13  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 8   sb_model_name_or_path_all-mpnet-base-v1_hs_min...
# 21  sb_model_name_or_path_all-mpnet-base-v1_hs_min...
# 19  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 6   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 3   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 12  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 18  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
#
#    hyperparameters.sbert_params.model_name_or_path  \
# 11                               all-mpnet-base-v1
# 17                               all-mpnet-base-v1
# 15                               all-mpnet-base-v1
# 4                                all-MiniLM-L12-v1
# 2                                all-mpnet-base-v1
# 1                                all-MiniLM-L12-v1
# 10                               all-MiniLM-L12-v1
# 16                               all-mpnet-base-v1
# 9                                all-MiniLM-L12-v1
# 23                               all-MiniLM-L12-v1
# 7                                all-MiniLM-L12-v1
# 22                               all-MiniLM-L12-v1
# 0                                all-MiniLM-L12-v1
# 5                                all-MiniLM-L12-v1
# 20                               all-MiniLM-L12-v1
# 14                               all-MiniLM-L12-v1
# 13                               all-MiniLM-L12-v1
# 8                                all-mpnet-base-v1
# 21                               all-mpnet-base-v1
# 19                               all-MiniLM-L12-v1
# 6                                all-MiniLM-L12-v1
# 3                                all-MiniLM-L12-v1
# 12                               all-MiniLM-L12-v1
# 18                               all-MiniLM-L12-v1
#
#    hyperparameters.vocab_tokenizer_params.ngram_range  ...  \
# 11                                             [1, 2]  ...
# 17                                             [1, 2]  ...
# 15                                             [1, 2]  ...
# 4                                              [1, 2]  ...
# 2                                              [1, 2]  ...
# 1                                              [1, 2]  ...
# 10                                             [1, 2]  ...
# 16                                             [1, 2]  ...
# 9                                              [1, 2]  ...
# 23                                             [1, 2]  ...
# 7                                              [1, 2]  ...
# 22                                             [1, 2]  ...
# 0                                              [1, 2]  ...
# 5                                              [1, 2]  ...
# 20                                             [1, 2]  ...
# 14                                             [1, 2]  ...
# 13                                             [1, 2]  ...
# 8                                              [1, 2]  ...
# 21                                             [1, 2]  ...
# 19                                             [1, 2]  ...
# 6                                              [1, 2]  ...
# 3                                              [1, 2]  ...
# 12                                             [1, 2]  ...
# 18                                             [1, 2]  ...
#
#     hyperparameters.umap_params.low_memory  \
# 11                                   False
# 17                                   False
# 15                                   False
# 4                                    False
# 2                                    False
# 1                                    False
# 10                                   False
# 16                                   False
# 9                                    False
# 23                                   False
# 7                                    False
# 22                                   False
# 0                                    False
# 5                                    False
# 20                                   False
# 14                                   False
# 13                                   False
# 8                                    False
# 21                                   False
# 19                                   False
# 6                                    False
# 3                                    False
# 12                                   False
# 18                                   False
#
#     hyperparameters.umap_params.random_state  \
# 11                                      None
# 17                                      None
# 15                                      None
# 4                                       None
# 2                                       None
# 1                                       None
# 10                                      None
# 16                                      None
# 9                                       None
# 23                                      None
# 7                                       None
# 22                                      None
# 0                                       None
# 5                                       None
# 20                                      None
# 14                                      None
# 13                                      None
# 8                                       None
# 21                                      None
# 19                                      None
# 6                                       None
# 3                                       None
# 12                                      None
# 18                                      None
#
#    hyperparameters.hdbscan_params.metric  \
# 11                             euclidean
# 17                             euclidean
# 15                             euclidean
# 4                              euclidean
# 2                              euclidean
# 1                              euclidean
# 10                             euclidean
# 16                             euclidean
# 9                              euclidean
# 23                             euclidean
# 7                              euclidean
# 22                             euclidean
# 0                              euclidean
# 5                              euclidean
# 20                             euclidean
# 14                             euclidean
# 13                             euclidean
# 8                              euclidean
# 21                             euclidean
# 19                             euclidean
# 6                              euclidean
# 3                              euclidean
# 12                             euclidean
# 18                             euclidean
#
#     hyperparameters.hdbscan_params.prediction_data  \
# 11                                            True
# 17                                            True
# 15                                            True
# 4                                             True
# 2                                             True
# 1                                             True
# 10                                            True
# 16                                            True
# 9                                             True
# 23                                            True
# 7                                             True
# 22                                            True
# 0                                             True
# 5                                             True
# 20                                            True
# 14                                            True
# 13                                            True
# 8                                             True
# 21                                            True
# 19                                            True
# 6                                             True
# 3                                             True
# 12                                            True
# 18                                            True
#
#    hyperparameters.hdbscan_params.min_samples  \
# 11                                         40
# 17                                         10
# 15                                         30
# 4                                          10
# 2                                          40
# 1                                          40
# 10                                         30
# 16                                         50
# 9                                          50
# 23                                         50
# 7                                          20
# 22                                         10
# 0                                          30
# 5                                          50
# 20                                         50
# 14                                         10
# 13                                         50
# 8                                          40
# 21                                         10
# 19                                         50
# 6                                          40
# 3                                          10
# 12                                         30
# 18                                         10
#
#     hyperparameters.hdbscan_params.min_cluster_size  \
# 11                                              180
# 17                                              120
# 15                                               90
# 4                                                90
# 2                                               200
# 1                                               180
# 10                                              120
# 16                                              120
# 9                                               180
# 23                                              120
# 7                                               200
# 22                                               30
# 0                                               180
# 5                                               150
# 20                                              150
# 14                                               60
# 13                                               60
# 8                                                90
# 21                                               60
# 19                                               90
# 6                                                30
# 3                                                30
# 12                                               30
# 18                                               30
#
#    hyperparameters.bertopic_params.language  \
# 11                                  english
# 17                                  english
# 15                                  english
# 4                                   english
# 2                                   english
# 1                                   english
# 10                                  english
# 16                                  english
# 9                                   english
# 23                                  english
# 7                                   english
# 22                                  english
# 0                                   english
# 5                                   english
# 20                                  english
# 14                                  english
# 13                                  english
# 8                                   english
# 21                                  english
# 19                                  english
# 6                                   english
# 3                                   english
# 12                                  english
# 18                                  english
#
#    hyperparameters.bertopic_params.calculate_probabilities  \
# 11                                               True
# 17                                               True
# 15                                               True
# 4                                                True
# 2                                                True
# 1                                                True
# 10                                               True
# 16                                               True
# 9                                                True
# 23                                               True
# 7                                                True
# 22                                               True
# 0                                                True
# 5                                                True
# 20                                               True
# 14                                               True
# 13                                               True
# 8                                                True
# 21                                               True
# 19                                               True
# 6                                                True
# 3                                                True
# 12                                               True
# 18                                               True
#
#     hyperparameters.bertopic_params.top_n_words  \
# 11                                           10
# 17                                           10
# 15                                           10
# 4                                            10
# 2                                            10
# 1                                            20
# 10                                           20
# 16                                           20
# 9                                            30
# 23                                           20
# 7                                            20
# 22                                           10
# 0                                            30
# 5                                            30
# 20                                           30
# 14                                           20
# 13                                           20
# 8                                            30
# 21                                           30
# 19                                           30
# 6                                            30
# 3                                            20
# 12                                           20
# 18                                           20
#
#     hyperparameters.bertopic_params.nr_topics
# 11                                         71
# 17                                         81
# 15                                         51
# 4                                          41
# 2                                          11
# 1                                          61
# 10                                         81
# 16                                         31
# 9                                          81
# 23                                         51
# 7                                          31
# 22                                         31
# 0                                          51
# 5                                          91
# 20                                         71
# 14                                         91
# 13                                        101
# 8                                          71
# 21                                         31
# 19                                         91
# 6                                          51
# 3                                          71
# 12                                         31
# 18                                         11
#
# [24 rows x 25 columns]

# %%
aaa[aaa['hyperparameters.sbert_params.model_name_or_path'] == 'all-MiniLM-L12-v1']
# Out:
#       c_npmi       c_v    u_mass     c_uci  topic_diversity  inverted_rbo  \
# 4   0.137412  0.713508 -0.226645  1.238540         0.718421      0.961122
# 1   0.111151  0.744181 -0.152728  0.891481         0.605085      0.945372
# 10  0.110444  0.719416 -0.227431  0.941981         0.680769      0.977346
# 9   0.100998  0.761304 -0.160130  0.824367         0.674359      0.971981
# 23  0.100161  0.719013 -0.165695  0.755407         0.636735      0.953011
# 7   0.099775  0.740856 -0.177363  0.686020         0.575862      0.913845
# 22  0.092475  0.629878 -0.465147  0.468985         0.840000      0.984671
# 0   0.092217  0.753588 -0.150548  0.645419         0.606250      0.951025
# 5   0.091976  0.753699 -0.143123  0.690079         0.657303      0.976477
# 20  0.091074  0.745403 -0.152650  0.678093         0.668116      0.968834
# 14  0.091014  0.689310 -0.278926  0.604335         0.723596      0.983895
# 13  0.088310  0.686396 -0.326609  0.553766         0.704082      0.984155
# 19  0.076788  0.702512 -0.255096  0.427047         0.690909      0.979583
# 6   0.071857  0.700117 -0.217763  0.289676         0.750000      0.983080
# 3   0.071528  0.648377 -0.303749  0.202981         0.768571      0.987691
# 12  0.061402  0.637311 -0.297421 -0.012197         0.780000      0.977916
# 18  0.057235  0.624205 -0.201727 -0.263578         0.910000      0.982728
#
#     pairwise_jaccard_similarity  \
# 4                      0.035787
# 1                      0.060758
# 10                     0.024298
# 9                      0.031359
# 23                     0.048740
# 7                      0.091492
# 22                     0.013068
# 0                      0.053354
# 5                      0.025502
# 20                     0.033474
# 14                     0.015741
# 13                     0.015548
# 19                     0.021892
# 6                      0.016910
# 3                      0.011415
# 12                     0.020359
# 18                     0.013125
#
#                                            model_name  \
# 4   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 1   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 10  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 9   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 23  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 7   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 22  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 0   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 5   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 20  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 14  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 13  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 19  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 6   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 3   sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 12  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
# 18  sb_model_name_or_path_all-MiniLM-L12-v1_hs_min...
#
#    hyperparameters.sbert_params.model_name_or_path  \
# 4                                all-MiniLM-L12-v1
# 1                                all-MiniLM-L12-v1
# 10                               all-MiniLM-L12-v1
# 9                                all-MiniLM-L12-v1
# 23                               all-MiniLM-L12-v1
# 7                                all-MiniLM-L12-v1
# 22                               all-MiniLM-L12-v1
# 0                                all-MiniLM-L12-v1
# 5                                all-MiniLM-L12-v1
# 20                               all-MiniLM-L12-v1
# 14                               all-MiniLM-L12-v1
# 13                               all-MiniLM-L12-v1
# 19                               all-MiniLM-L12-v1
# 6                                all-MiniLM-L12-v1
# 3                                all-MiniLM-L12-v1
# 12                               all-MiniLM-L12-v1
# 18                               all-MiniLM-L12-v1
#
#    hyperparameters.vocab_tokenizer_params.ngram_range  ...  \
# 4                                              [1, 2]  ...
# 1                                              [1, 2]  ...
# 10                                             [1, 2]  ...
# 9                                              [1, 2]  ...
# 23                                             [1, 2]  ...
# 7                                              [1, 2]  ...
# 22                                             [1, 2]  ...
# 0                                              [1, 2]  ...
# 5                                              [1, 2]  ...
# 20                                             [1, 2]  ...
# 14                                             [1, 2]  ...
# 13                                             [1, 2]  ...
# 19                                             [1, 2]  ...
# 6                                              [1, 2]  ...
# 3                                              [1, 2]  ...
# 12                                             [1, 2]  ...
# 18                                             [1, 2]  ...
#
#     hyperparameters.umap_params.low_memory  \
# 4                                    False
# 1                                    False
# 10                                   False
# 9                                    False
# 23                                   False
# 7                                    False
# 22                                   False
# 0                                    False
# 5                                    False
# 20                                   False
# 14                                   False
# 13                                   False
# 19                                   False
# 6                                    False
# 3                                    False
# 12                                   False
# 18                                   False
#
#     hyperparameters.umap_params.random_state  \
# 4                                       None
# 1                                       None
# 10                                      None
# 9                                       None
# 23                                      None
# 7                                       None
# 22                                      None
# 0                                       None
# 5                                       None
# 20                                      None
# 14                                      None
# 13                                      None
# 19                                      None
# 6                                       None
# 3                                       None
# 12                                      None
# 18                                      None
#
#    hyperparameters.hdbscan_params.metric  \
# 4                              euclidean
# 1                              euclidean
# 10                             euclidean
# 9                              euclidean
# 23                             euclidean
# 7                              euclidean
# 22                             euclidean
# 0                              euclidean
# 5                              euclidean
# 20                             euclidean
# 14                             euclidean
# 13                             euclidean
# 19                             euclidean
# 6                              euclidean
# 3                              euclidean
# 12                             euclidean
# 18                             euclidean
#
#     hyperparameters.hdbscan_params.prediction_data  \
# 4                                             True
# 1                                             True
# 10                                            True
# 9                                             True
# 23                                            True
# 7                                             True
# 22                                            True
# 0                                             True
# 5                                             True
# 20                                            True
# 14                                            True
# 13                                            True
# 19                                            True
# 6                                             True
# 3                                             True
# 12                                            True
# 18                                            True
#
#    hyperparameters.hdbscan_params.min_samples  \
# 4                                          10
# 1                                          40
# 10                                         30
# 9                                          50
# 23                                         50
# 7                                          20
# 22                                         10
# 0                                          30
# 5                                          50
# 20                                         50
# 14                                         10
# 13                                         50
# 19                                         50
# 6                                          40
# 3                                          10
# 12                                         30
# 18                                         10
#
#     hyperparameters.hdbscan_params.min_cluster_size  \
# 4                                                90
# 1                                               180
# 10                                              120
# 9                                               180
# 23                                              120
# 7                                               200
# 22                                               30
# 0                                               180
# 5                                               150
# 20                                              150
# 14                                               60
# 13                                               60
# 19                                               90
# 6                                                30
# 3                                                30
# 12                                               30
# 18                                               30
#
#    hyperparameters.bertopic_params.language  \
# 4                                   english
# 1                                   english
# 10                                  english
# 9                                   english
# 23                                  english
# 7                                   english
# 22                                  english
# 0                                   english
# 5                                   english
# 20                                  english
# 14                                  english
# 13                                  english
# 19                                  english
# 6                                   english
# 3                                   english
# 12                                  english
# 18                                  english
#
#    hyperparameters.bertopic_params.calculate_probabilities  \
# 4                                                True
# 1                                                True
# 10                                               True
# 9                                                True
# 23                                               True
# 7                                                True
# 22                                               True
# 0                                                True
# 5                                                True
# 20                                               True
# 14                                               True
# 13                                               True
# 19                                               True
# 6                                                True
# 3                                                True
# 12                                               True
# 18                                               True
#
#     hyperparameters.bertopic_params.top_n_words  \
# 4                                            10
# 1                                            20
# 10                                           20
# 9                                            30
# 23                                           20
# 7                                            20
# 22                                           10
# 0                                            30
# 5                                            30
# 20                                           30
# 14                                           20
# 13                                           20
# 19                                           30
# 6                                            30
# 3                                            20
# 12                                           20
# 18                                           20
#
#     hyperparameters.bertopic_params.nr_topics
# 4                                          41
# 1                                          61
# 10                                         81
# 9                                          81
# 23                                         51
# 7                                          31
# 22                                         31
# 0                                          51
# 5                                          91
# 20                                         71
# 14                                         91
# 13                                        101
# 19                                         91
# 6                                          51
# 3                                          71
# 12                                         31
# 18                                         11
#
# [17 rows x 25 columns]

# %%
# only show the columns within the search_space
search_space = run_config['search_space']

# flatten the dictionary
search_space_flattened = flatten_dict({'hyperparameters': search_space}, sep='.')
search_space_flattened
# Out:
# {'hyperparameters.num_topics': [10, 20, 30],
#  'hyperparameters.decay': [0.7, 0.8, 0.9],
#  'hyperparameters.offset': [16, 64, 128]}

# %%
bbb = log_history_df[metrics_names + list(search_space_flattened.keys())]
bbb
# Out:
#       u_mass       c_v     c_uci    c_npmi  topic_diversity  inverted_rbo  \
# 0 -12.384272  0.446707 -4.974539 -0.144084         0.893333      0.958782
# 1 -10.097818  0.469527 -4.300028 -0.120668         0.835000      0.946205
# 2  -6.049482  0.534362 -2.594367 -0.050303         0.780000      0.885862
# 3  -7.652754  0.456655 -3.448683 -0.099818         0.760000      0.921964
# 4  -5.359241  0.557811 -2.179838 -0.033814         0.790000      0.905221
# 5  -6.110928  0.463247 -2.870690 -0.077491         0.740000      0.893998
# 6 -10.890116  0.417424 -4.769389 -0.141470         0.816667      0.924801
# 7  -7.868889  0.372327 -3.975141 -0.122213         0.606667      0.806936
# 8  -8.912569  0.521910 -4.325420 -0.129421         0.830000      0.946658
# 9 -10.800261  0.449660 -4.811866 -0.145979         0.836667      0.931040
#
#    pairwise_jaccard_similarity  hyperparameters.num_topics  \
# 0                     0.029855                          30
# 1                     0.037282                          20
# 2                     0.056947                          10
# 3                     0.051122                          20
# 4                     0.048964                          10
# 5                     0.085308                          10
# 6                     0.050146                          30
# 7                     0.121393                          30
# 8                     0.036871                          20
# 9                     0.043880                          30
#
#    hyperparameters.decay  hyperparameters.offset
# 0                    0.7                     128
# 1                    0.8                      64
# 2                    0.8                      16
# 3                    0.9                      16
# 4                    0.7                      16
# 5                    0.8                     128
# 6                    0.8                      64
# 7                    0.8                     128
# 8                    0.8                      16
# 9                    0.9                      16

# %%
bbb.sort_values(by='c_npmi', ascending=False)
# Out:
#       u_mass       c_v     c_uci    c_npmi  topic_diversity  inverted_rbo  \
# 4  -5.359241  0.557811 -2.179838 -0.033814         0.790000      0.905221
# 2  -6.049482  0.534362 -2.594367 -0.050303         0.780000      0.885862
# 5  -6.110928  0.463247 -2.870690 -0.077491         0.740000      0.893998
# 3  -7.652754  0.456655 -3.448683 -0.099818         0.760000      0.921964
# 1 -10.097818  0.469527 -4.300028 -0.120668         0.835000      0.946205
# 7  -7.868889  0.372327 -3.975141 -0.122213         0.606667      0.806936
# 8  -8.912569  0.521910 -4.325420 -0.129421         0.830000      0.946658
# 6 -10.890116  0.417424 -4.769389 -0.141470         0.816667      0.924801
# 0 -12.384272  0.446707 -4.974539 -0.144084         0.893333      0.958782
# 9 -10.800261  0.449660 -4.811866 -0.145979         0.836667      0.931040
#
#    pairwise_jaccard_similarity  hyperparameters.num_topics  \
# 4                     0.048964                          10
# 2                     0.056947                          10
# 5                     0.085308                          10
# 3                     0.051122                          20
# 1                     0.037282                          20
# 7                     0.121393                          30
# 8                     0.036871                          20
# 6                     0.050146                          30
# 0                     0.029855                          30
# 9                     0.043880                          30
#
#    hyperparameters.decay  hyperparameters.offset
# 4                    0.7                      16
# 2                    0.8                      16
# 5                    0.8                     128
# 3                    0.9                      16
# 1                    0.8                      64
# 7                    0.8                     128
# 8                    0.8                      16
# 6                    0.8                      64
# 0                    0.7                     128
# 9                    0.9                      16
