# %% [markdown]
# Read df from pickle file

# %%
import os
from pathlib import Path
import re
import pandas as pd

# %%
def check_for_checkpoint(dataset_folder:Path, base_file: Path):
    '''Search for any checkpoints file. Return the latest checkpoint file (with the largest index), and the index of the file.

    Else return the base_file

    params:
    dataset_folder: the folder contains a specific dataset and all checkpoints.
    base_file: the raw file without any checkpoints suffix.
    '''
    all_pkl = []
    for root, dirs, files in os.walk(dataset_folder):
        all_pkl = list(map(lambda f: Path(root, f), files))
        all_pkl = [p for p in all_pkl if p.suffix == '.pkl']
        break       # only scan for 1 level, not looking for directories inside the folder

    # get checkpoint files, containing the keyword 'ckpt'
    checkpoint_files = [f for f in all_pkl if "ckpt" in f.name]

    if checkpoint_files:

        get_index = lambda f: int(re.search(f"{base_file.stem}_ckpt_([0-9]*){base_file.suffix}", f.name)[1])
        # filename looks like 'file_name' + '_ckpt_' + '123' + '.pkl'
        largest_index_file = max(
            checkpoint_files, key=get_index
        )
        largest_index = get_index(largest_index_file)

        return largest_index_file, largest_index
    else:
        return base_file, 0
    
def load_pickle(path_to_load:Path) -> pd.DataFrame:
    df = pd.read_pickle(path_to_load)
    print('\n')
    print(f'Successfully loaded df from {str(path_to_load)}')
    # print(df.head())
    return df

# %%
dataset_folder = Path('run_20230927').resolve()
base_file = Path(dataset_folder, 'dataset_noheart_20230927.pkl')

# this will get the latest checkpoint
df_filepath, curr_ckpt_index = check_for_checkpoint(dataset_folder, base_file)

# %%
df = load_pickle(df_filepath)

print(df.head(30))
# Out:
# Successfully loaded df from /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/run_20230927/dataset_noheart_20230927_ckpt_003.pkl
#     dataset_index  app_id                                     app_name  \
# 0          746006  208140          ENDLESS™ Space - Definitive Edition
# 1          693423  206440                                  To the Moon
# 2         4766237  365590                    Tom Clancy's The Division
# 3         3029812  261720          Holy Avatar vs. Maidens of the Dead
# 4         2634999  250340                                    Blockland
# 5         2581679  248630                                Kingdoms Rise
# 6         3560283  289070                  Sid Meier's Civilization VI
# 7         2053284  236390                                  War Thunder
# 8          435035  200210                   Realm of the Mad God Exalt
# 9          524907  203140                           Hitman: Absolution
# 10        1157369  218620                                     PAYDAY 2
# 11        5419737     420                     Half-Life 2: Episode Two
# 12        1971500  233740                  Organ Trail: Director's Cut
# 13        2270015  241320                                    Ittle Dew
# 14        4555093   34900                                     Bad Rats
# 15        4349556  333930                                   Dirty Bomb
# 16         292295   12120                                          nan
# 17        2248774     240                       Counter-Strike: Source
# 18        3454651  282800                            100% Orange Juice
# 19        5680210   45760                      Ultra Street Fighter IV
# 20        4584672  351640                                Eternal Senia
# 21        2668995  250900                The Binding of Isaac: Rebirth
# 22        3308412  272470  The Incredible Adventures of Van Helsing II
# 23        2620666  250180                                 METAL SLUG 3
# 24        4574366  351340                                   Belladonna
# 25        3645424  292030                     The Witcher 3: Wild Hunt
# 26        2170420  238960                                Path of Exile
# 27        2205975  239160                                        Thief
# 28        4862969  374320                              DARK SOULS™ III
# 29        4186518  322500                                     SUPERHOT
#
#                                           review_text  review_score  \
# 0   This game has space-battles, tech-trees and sp...             1
# 1   Very cute emotional story. Less game play aspe...             1
# 2                             FU Ubisoft and F the DZ            -1
# 3   It is a one joke game that fortunately doesn't...            -1
# 4   I like being able to be giant and blockland le...             1
# 5                                 Early Access Review            -1
# 6   Shares a lot of the look of Civ V, but much mo...             1
# 7                Meh. Microtransactions. That is all.            -1
# 8   Too hard for beginners if you die you lose all...            -1
# 9   I enjoyed the campaign, solid game to play thr...             1
# 10  want to learn how to repair drills? play this ...             1
# 11  Nominate this for the 'GAME THAT DESERVES A SE...             1
# 12  Fun game to pass time or when you need to take...             1
# 13  A part of me really doesn't want to recommend ...             1
# 14                                 Dont be a bad rat.            -1
# 15  More glitches than in dayz standalone examples...            -1
# 16  Honestly, i'veonly completed the storyline onc...             1
# 17                        Ruined my life. Five stars.             1
# 18  Big rockets? Check. Clutch out of nowhere vict...             1
# 19  If you like fighting streets I recommend you u...             1
# 20  this game is a game that i really enjoyed. i l...             1
# 21                            This game is really fun             1
# 22  The game is unplayable in coop, the game crash...            -1
# 23  I'll start by saying this is my favorite game ...            -1
# 24  so terribly short.. it could be greatly expand...            -1
# 25                 Yup, defenitely gona buy Witcher 4             1
# 26      It is probably the greatest game of it's kind             1
# 27  I found this game very entertaining. Alot of v...             1
# 28  My honest review of the amazing Dark Souls III...             1
# 29         Still a better love story then twighlight.             1
#
#     review_votes                                           response  \
# 0              0  {"positive": 0.8000, "neutral": 0.2000, "negat...
# 1              0  {"positive": 1.0000, "neutral": 0.0000, "negat...
# 2              1  {"positive": 0.0000, "neutral": 0.0000, "negat...
# 3              0  {"positive": 0.0000, "neutral": 0.0000, "negat...
# 4              0  {"positive": 1.0000, "neutral": 0.0000, "negat...
# 5              0  {\n  "positive": 0.0000,\n  "neutral": 0.0000,...
# 6              0  {\n    "positive": 0.8,\n    "neutral": 0.2,\n...
# 7              0  {\n    "positive": 0,\n    "neutral": 1,\n    ...
# 8              0       {"positive": 0, "neutral": 0, "negative": 1}
# 9              0   {"positive": 0.5, "neutral": 0.5, "negative": 0}
# 10             0   {"positive": 0.8, "neutral": 0.2, "negative": 0}
# 11             0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 12             0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 13             0  {"positive": 0.6, "neutral": 0.2, "negative": ...
# 14             0                                                NA.
# 15             0  {\n    "positive": 0,\n    "neutral": 0.33,\n ...
# 16             0  {"positive": 0.2, "neutral": 0.6, "negative": ...
# 17             0  {\n  "positive": 1.0,\n  "neutral": 0.0,\n  "n...
# 18             1  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 19             0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 20             0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 21             0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 22             0       {"positive": 0, "neutral": 0, "negative": 1}
# 23             0  {"positive": 0.2, "neutral": 0.6, "negative": ...
# 24             0  {\n  "positive": 0.6,\n  "neutral": 0.4,\n  "n...
# 25             0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 26             0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 27             0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 28             1  {\n  "positive": 1.0,\n  "neutral": 0.0,\n  "n...
# 29             0  {"positive": 1.0, "neutral": 0.0, "negative": ...
#
#     total_token_used
# 0                201
# 1                142
# 2                138
# 3                235
# 4                149
# 5                136
# 6                147
# 7                126
# 8                138
# 9                142
# 10               128
# 11               138
# 12               154
# 13               562
# 14               103
# 15               177
# 16               143
# 17               133
# 18               203
# 19               144
# 20               165
# 21               125
# 22               161
# 23               246
# 24               162
# 25               137
# 26               127
# 27               192
# 28               152
# 29               126

# %%
df.iloc[50:70]
# Out:
#     dataset_index  app_id                                    app_name  \
# 50        1971365  233740                 Organ Trail: Director's Cut
# 51        4022172  312530                                   Duck Game
# 52        5742735   47810      Dragon Age: Origins - Ultimate Edition
# 53        5423590  420100                        CLANNAD Side Stories
# 54        2402376  242920                                    Banished
# 55        4766094  365590                   Tom Clancy's The Division
# 56        4680954  359550              Tom Clancy's Rainbow Six Siege
# 57        1252922  219890                                 Antichamber
# 58         674667  206420                               Saints Row IV
# 59        5514462   43110                                         nan
# 60        6413823   99700                                    NightSky
# 61        1911438  232910                         TrackMania² Stadium
# 62        6318767    8870                           BioShock Infinite
# 63        5782430   48700                      Mount & Blade: Warband
# 64         897285  211820                                   Starbound
# 65        3361973  275850                                No Man's Sky
# 66        1919268  233130                              Shadow Warrior
# 67        1717246  227700                                         nan
# 68         921703  211820                                   Starbound
# 69        4033015   31290  Back to the Future: Ep 1 - It's About Time
#
#                                           review_text  review_score  \
# 50  Nabbing this, especially while on sale, is mos...             1
# 51        Last Edited   09 February 2016       Sco...             1
# 52                                                nan             1
# 53  So I sign into steam and much to my surprise I...             1
# 54  Banished runs very smooth. The graphic is beau...             1
# 55  The game was fun. It was fun completing the mi...            -1
# 56  Rainbow Six Siege is definitley a great game! ...             1
# 57  Excellent game. Even more satisfying without w...             1
# 58  The game was AMAZING! Until I started getting ...             1
# 59  I don't normally recommend FPS games, but this...             1
# 60  Another game from a Humble bundle. Music was p...             1
# 61  I love this game. It is super simple, but hard...             1
# 62  I Played This In 7 Hours. I Think That's Actua...            -1
# 63               My parents told me to 'Get a life' .             1
# 64                                Early Access Review             1
# 65  Its as much art as it is game. Its genuinely c...             1
# 66  the game has intense head bob / camera sway ef...            -1
# 67  Fryepod quit and so did half the game..  They ...            -1
# 68                                Early Access Review             1
# 69  It's a classic point and click adventure game,...            -1
#
#     review_votes                                           response  \
# 50             0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 51             0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 52             0                                                 NA
# 53             1  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 54             0  {\n  "positive": 0.8,\n  "neutral": 0.1,\n  "n...
# 55             0  {"positive": 0.1, "neutral": 0.4, "negative": ...
# 56             0   {"positive": 0.9, "neutral": 0.1, "negative": 0}
# 57             0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 58             0  {"positive": 0.9, "neutral": 0.0, "negative": ...
# 59             0  {\n  "positive": 1.0,\n  "neutral": 0.0,\n  "n...
# 60             0
# 61             0
# 62             0
# 63             0
# 64             0
# 65             0
# 66             0
# 67             1
# 68             0
# 69             1
#
#     total_token_used
# 50               249
# 51               149
# 52               100
# 53              1361
# 54               377
# 55               476
# 56               347
# 57               148
# 58               132
# 59               171
# 60                -1
# 61                -1
# 62                -1
# 63                -1
# 64                -1
# 65                -1
# 66                -1
# 67                -1
# 68                -1
# 69                -1
