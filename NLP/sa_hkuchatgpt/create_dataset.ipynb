# %% [markdown]
# Prompt engineering 27-09-2023 ver
#
# Extract a subset of data from large dataset.

# %%
import pandas as pd
import numpy as np

from pathlib import Path
import random

random.seed(13)
# take 15% for both testing and training from original. Then among that 15%, 70% for training, 30% for testing.
p = 0.15

# NOTICE: change the dataset path to where your dataset.csv is.
dataset_path = Path('../fyp-workspace/dataset.csv')

# dataset = pd.read_csv(dataset_path, skiprows=lambda i: i > 0 and random.random() > p)
# dataset.head()

dataset = pd.read_csv(dataset_path)
dataset
# Out:
#          app_id        app_name  \
# 0            10  Counter-Strike
# 1            10  Counter-Strike
# 2            10  Counter-Strike
# 3            10  Counter-Strike
# 4            10  Counter-Strike
# ...         ...             ...
# 6417101   99910  Puzzle Pirates
# 6417102   99910  Puzzle Pirates
# 6417103   99910  Puzzle Pirates
# 6417104   99910  Puzzle Pirates
# 6417105   99910  Puzzle Pirates
#
#                                                review_text  review_score  \
# 0                                          Ruined my life.             1
# 1        This will be more of a ''my experience with th...             1
# 2                            This game saved my virginity.             1
# 3        • Do you like original games? • Do you like ga...             1
# 4                 Easy to learn, hard to master.                       1
# ...                                                    ...           ...
# 6417101  I really ove this game but it needs somethings...            -1
# 6417102  Used to play Puzzel Pirates 'way back when', b...            -1
# 6417103  This game was aright, though a bit annoying. W...            -1
# 6417104  I had a nice review to recommend this game, bu...            -1
# 6417105  The puzzles in this game are fun, but you have...            -1
#
#          review_votes
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   1
# ...               ...
# 6417101             0
# 6417102             0
# 6417103             0
# 6417104             0
# 6417105             0
#
# [6417106 rows x 5 columns]

# %%
# notice there are some null values
dataset.isnull().sum()
# Out:
# app_id               0
# app_name        183234
# review_text       7305
# review_score         0
# review_votes         0
# dtype: int64

# %%
# We remove rows that contains null values (for both column app_name and review_text)
dataset = dataset[dataset['app_name'].isnull() == False]

dataset = dataset[dataset['review_text'].isnull() == False]

dataset.isnull().sum()
# Out:
# app_id          0
# app_name        0
# review_text     0
# review_score    0
# review_votes    0
# dtype: int64

# %%
# convert columns to string type

dataset['review_text'] = dataset['review_text'].apply(str, 1)
dataset['app_name'] = dataset['app_name'].apply(str, 1)
dataset.head(10)
# Out:
# /var/folders/hm/n8540hpn7xd1f0pw3_qnsp4r0000gn/T/ipykernel_51600/1148837174.py:3: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   dataset['review_text'] = dataset['review_text'].apply(str, 1)
# /var/folders/hm/n8540hpn7xd1f0pw3_qnsp4r0000gn/T/ipykernel_51600/1148837174.py:4: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   dataset['app_name'] = dataset['app_name'].apply(str, 1)
#    app_id        app_name                                        review_text  \
# 0      10  Counter-Strike                                    Ruined my life.
# 1      10  Counter-Strike  This will be more of a ''my experience with th...
# 2      10  Counter-Strike                      This game saved my virginity.
# 3      10  Counter-Strike  • Do you like original games? • Do you like ga...
# 4      10  Counter-Strike           Easy to learn, hard to master.
# 5      10  Counter-Strike             No r8 revolver, 10/10 will play again.
# 6      10  Counter-Strike          Still better than Call of Duty: Ghosts...
# 7      10  Counter-Strike  cant buy skins, cases, keys, stickers - gaben ...
# 8      10  Counter-Strike  Counter-Strike: Ok, after 9 years of unlimited...
# 9      10  Counter-Strike  Every server is spanish or french. I can now f...
#
#    review_score  review_votes
# 0             1             0
# 1             1             1
# 2             1             0
# 3             1             0
# 4             1             1
# 5             1             1
# 6             1             1
# 7             1             1
# 8             1             1
# 9             1             0

# %%
# we notice that there are some rows onlu contain "Early Access Review" -> not helpful to the analysis
# we remove these rows.

print("before removing:", dataset.shape)

dataset = dataset[dataset['review_text'].str.contains("Early Access Review") == False]

print("after removing:", dataset.shape)
# Out:
# before removing: (6226728, 5)
# after removing: (5238690, 5)

# %% [markdown]
# There are 988038 rows that contain only "Early Access Review", which is not helpful to the analysis

# %%
# remove comments that contain ♥ (means foul language)

dataset_noheart = dataset[dataset['review_text'].str.contains('♥') == False]
print(dataset_noheart.shape)
print(dataset.shape)
# Out:
# (4891928, 5)
# (5238690, 5)

# %%
# sample randomly for rows
dataset_sampled = dataset_noheart.sample(frac=p, random_state=13)       # keep the same random_state to create the same rows 

dataset_sampled
# Out:
#          app_id                                  app_name  \
# 4994864  383870                                 Firewatch
# 4540004  348250                           Google Earth VR
# 1656212   22610                       Alien Breed: Impact
# 2841416  252950                             Rocket League
# 4922442  379720                                      DOOM
# ...         ...                                       ...
# 931947   212070                             Star Conflict
# 2209901  239160                                     Thief
# 2222841  239820                           Game Dev Tycoon
# 5910051  506610  Five Nights at Freddy's: Sister Location
# 6072015     570                                    Dota 2
#
#                                                review_text  review_score  \
# 4994864  Honestly, I sat here for a few minutes to ques...             1
# 4540004  Words can not describe how awesome experience ...             1
# 1656212  is fun to play if you know others who woulod p...             1
# 2841416  Took away all my items after not playing for 2...            -1
# 4922442  I can play this with a really bad CPU (A10-580...             1
# ...                                                    ...           ...
# 931947                     Skrim in S P ace. Rift support.             1
# 2209901  There once was a time when I liked this game. ...            -1
# 2222841  This is one of my all time favorite games. I p...             1
# 5910051  This game is amazing!! The only glitch I exper...             1
# 6072015                             10/10 - Ruined my life             1
#
#          review_votes
# 4994864             0
# 4540004             0
# 1656212             0
# 2841416             0
# 4922442             0
# ...               ...
# 931947              0
# 2209901             0
# 2222841             0
# 5910051             0
# 6072015             0
#
# [733789 rows x 5 columns]

# %%
# reset index particularly for creating dataset
dataset_sampled.reset_index(inplace=True)
dataset_sampled = dataset_sampled.rename(columns={'index': 'dataset_index'})
dataset_sampled = dataset_sampled.sort_values(by=['dataset_index'])
dataset_sampled.reset_index(inplace=True, drop=True)

dataset_sampled
# Out:
#         dataset_index  app_id        app_name  \
# 0                   0      10  Counter-Strike
# 1                   7      10  Counter-Strike
# 2                  10      10  Counter-Strike
# 3                  17      10  Counter-Strike
# 4                  46      10  Counter-Strike
# ...               ...     ...             ...
# 733784        6417083   99910  Puzzle Pirates
# 733785        6417089   99910  Puzzle Pirates
# 733786        6417098   99910  Puzzle Pirates
# 733787        6417100   99910  Puzzle Pirates
# 733788        6417101   99910  Puzzle Pirates
#
#                                               review_text  review_score  \
# 0                                         Ruined my life.             1
# 1       cant buy skins, cases, keys, stickers - gaben ...             1
# 2                         Fire in the Hole Simulator 1999             1
# 3       When you crouch, you lift your feet in the air...             1
# 4       With only ~4000 hours of playtime (plus a few ...             1
# ...                                                   ...           ...
# 733784                                 really boring game            -1
# 733785  Rating based on current state of play, as per ...            -1
# 733786  This game is good but also horrible. Its fun t...            -1
# 733787  This game is good but also horrible. Its fun t...            -1
# 733788  I really ove this game but it needs somethings...            -1
#
#         review_votes
# 0                  0
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 733784             0
# 733785             0
# 733786             0
# 733787             0
# 733788             0
#
# [733789 rows x 6 columns]

# %%
# save the modified dataset as pickle
import datetime


filename = f'dataset_cleaned_heartless_sampled_{datetime.datetime.now().strftime("%Y%m%d")}.pkl'
save_path = Path(filename).resolve()
dataset_sampled.to_pickle(save_path)
print(f"Saved to: {save_path}")
# Out:
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927.pkl

# %% [markdown]
# ### Optional
#
# Saving the cleaned, heartless dataset to csv and pickle.

# %%
# optional

# save the cleaned dataset
dataset_noheart_tosave = dataset_noheart.reset_index()


filename = 'dataset_cleaned_heartless.csv'
save_path = Path(filename).resolve()
dataset_noheart_tosave.to_csv(save_path)

print(f"Saved to: {save_path}")
# Out:
# Saved to: dataset_cleaned_heartless.csv

# %%
filename_pkl = 'dataset_cleaned_heartless.pkl'
save_path_pkl = Path(filename_pkl).resolve()
dataset_noheart_tosave.to_pickle(save_path_pkl)

print(f"Saved to: {save_path_pkl}")
# Out:
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless.pkl

# %% [markdown]
# ------

# %% [markdown]
# Creating portions of the dataset (3000 per slices, create three slices)

# %%
import pandas as pd
from pathlib import Path
import random

dataset_sampled_path = Path("dataset_cleaned_heartless_sampled_20230927.pkl")
dataset_sampled = pd.read_pickle(dataset_sampled_path)

dataset_sampled
# Out:
#         dataset_index  app_id        app_name  \
# 0                   0      10  Counter-Strike
# 1                   7      10  Counter-Strike
# 2                  10      10  Counter-Strike
# 3                  17      10  Counter-Strike
# 4                  46      10  Counter-Strike
# ...               ...     ...             ...
# 733784        6417083   99910  Puzzle Pirates
# 733785        6417089   99910  Puzzle Pirates
# 733786        6417098   99910  Puzzle Pirates
# 733787        6417100   99910  Puzzle Pirates
# 733788        6417101   99910  Puzzle Pirates
#
#                                               review_text  review_score  \
# 0                                         Ruined my life.             1
# 1       cant buy skins, cases, keys, stickers - gaben ...             1
# 2                         Fire in the Hole Simulator 1999             1
# 3       When you crouch, you lift your feet in the air...             1
# 4       With only ~4000 hours of playtime (plus a few ...             1
# ...                                                   ...           ...
# 733784                                 really boring game            -1
# 733785  Rating based on current state of play, as per ...            -1
# 733786  This game is good but also horrible. Its fun t...            -1
# 733787  This game is good but also horrible. Its fun t...            -1
# 733788  I really ove this game but it needs somethings...            -1
#
#         review_votes
# 0                  0
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 733784             0
# 733785             0
# 733786             0
# 733787             0
# 733788             0
#
# [733789 rows x 6 columns]

# %%
# we shift them in random order.

dataset_sampled_suffled = dataset_sampled.sample(frac=1, random_state=42)   # add random_state for reproducability
dataset_sampled_suffled
# Out:
#         dataset_index  app_id                                        app_name  \
# 272004        2265312  240760                                     Wasteland 2
# 491809        4343173  333930                                      Dirty Bomb
# 549814        4866998  374320                                 DARK SOULS™ III
# 60739          456459  200510                             XCOM: Enemy Unknown
# 308277        2630163  250320                               The Wolf Among Us
# ...               ...     ...                                             ...
# 721406        6324774    8870                               BioShock Infinite
# 678684        6016504   56400  Warhammer 40,000: Dawn of War II - Retribution
# 162129        1262311  219990                                       Grim Dawn
# 729820        6384679   94400                                         Nidhogg
# 515167        4563862  349720                                 Audition Online
#
#                                               review_text  review_score  \
# 272004  If you're hoping for anything like fallout 1 &...            -1
# 491809             The version of Brink that doesn't suck             1
# 549814            oh my got, 10 casuls of 10. now get gut             1
# 60739   A very engaging turn pased stratigy game. Any ...             1
# 308277  9.5/10 Great story. word can't do this one jus...             1
# ...                                                   ...           ...
# 721406  Absolutely Amazing Game! Definitely a must pla...             1
# 678684  Really good real time strategy game.  This gam...             1
# 162129  Right now I play nothing else. It's that good....             1
# 729820  Simple, yet endlessly playable. Also, a fantas...             1
# 515167        The Dark Souls of rhythm based dance games.             1
#
#         review_votes
# 272004             1
# 491809             1
# 549814             1
# 60739              0
# 308277             0
# ...              ...
# 721406             0
# 678684             0
# 162129             0
# 729820             0
# 515167             1
#
# [733789 rows x 6 columns]

# %%
chunk_size = 3000

def slice_dataframe(df, chunk_size):
    '''Creating smaller chunks of dataframes. Remaining rows will be put in the last chunk
    
    params:
    df: the large dataframe
    chunk_size: number of rows in each smaller chunk'''
    num_rows = len(df)
    num_chunks = num_rows // chunk_size
    remaining_rows = num_rows // chunk_size

    for i in range(num_chunks):
        start = i * chunk_size
        end = min((i + 1) * chunk_size, num_rows)
        yield df[start:end]

    if remaining_rows > 0:
        yield df[num_chunks * chunk_size:]

sliced_dfs = [df for df in slice_dataframe(dataset_sampled_suffled, chunk_size)]

# reset index (for HKU ChatGPT)
sliced_dfs = list(map(lambda df: df.reset_index(drop=True), sliced_dfs))

# %%
sliced_dfs[0]
# Out:
#       dataset_index  app_id                        app_name  \
# 0           2265312  240760                     Wasteland 2
# 1           4343173  333930                      Dirty Bomb
# 2           4866998  374320                 DARK SOULS™ III
# 3            456459  200510             XCOM: Enemy Unknown
# 4           2630163  250320               The Wolf Among Us
# ...             ...     ...                             ...
# 2995         836478  210770                       Sanctum 2
# 2996        3583526  290340                         Armello
# 2997        2317736  242050  Assassin's Creed IV Black Flag
# 2998        3566527  289130                 ENDLESS™ Legend
# 2999         386864   17410                   Mirror's Edge
#
#                                             review_text  review_score  \
# 0     If you're hoping for anything like fallout 1 &...            -1
# 1                The version of Brink that doesn't suck             1
# 2               oh my got, 10 casuls of 10. now get gut             1
# 3     A very engaging turn pased stratigy game. Any ...             1
# 4     9.5/10 Great story. word can't do this one jus...             1
# ...                                                 ...           ...
# 2995  It's really fun - but pretty much impossible w...             1
# 2996  You play one charakter with unique abilites li...             1
# 2997  Best 'Pirates of the Caribbean'-game on the ma...             1
# 2998  I've been taking care of a waffle under my bed...             1
# 2999  Lag's on lowest graphics with a decent pc. Ove...             1
#
#       review_votes
# 0                1
# 1                1
# 2                1
# 3                0
# 4                0
# ...            ...
# 2995             1
# 2996             0
# 2997             1
# 2998             1
# 2999             0
#
# [3000 rows x 6 columns]

# %%
chunk_folder = Path(dataset_sampled_path.stem + '/')
if not chunk_folder.exists():
    chunk_folder.mkdir()

for i, sliced_df in enumerate(sliced_dfs):
    filename = f'{dataset_sampled_path.stem}_chunk_{i:03}.pkl'
    save_path = chunk_folder.joinpath(filename).resolve()
    sliced_df.to_pickle(save_path)
    print(f"Saved to: {save_path}")
# Out:
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_000.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_001.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_002.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_003.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_004.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_005.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_006.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_007.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_008.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_009.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_010.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_011.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_012.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_013.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_014.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_015.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_016.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_017.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_018.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_019.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_020.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_021.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_022.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_023.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_024.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_025.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_026.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_027.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_028.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_029.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_030.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_031.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_032.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_033.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_034.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_035.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_036.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_037.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_038.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_039.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_040.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_041.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_042.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_043.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_044.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_045.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_046.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_047.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_048.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_049.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_050.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_051.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_052.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_053.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_054.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_055.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_056.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_057.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_058.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_059.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_060.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_061.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_062.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_063.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_064.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_065.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_066.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_067.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_068.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_069.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_070.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_071.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_072.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_073.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_074.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_075.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_076.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_077.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_078.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_079.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_080.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_081.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_082.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_083.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_084.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_085.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_086.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_087.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_088.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_089.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_090.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_091.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_092.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_093.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_094.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_095.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_096.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_097.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_098.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_099.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_100.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_101.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_102.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_103.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_104.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_105.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_106.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_107.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_108.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_109.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_110.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_111.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_112.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_113.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_114.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_115.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_116.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_117.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_118.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_119.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_120.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_121.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_122.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_123.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_124.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_125.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_126.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_127.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_128.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_129.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_130.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_131.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_132.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_133.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_134.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_135.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_136.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_137.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_138.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_139.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_140.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_141.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_142.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_143.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_144.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_145.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_146.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_147.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_148.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_149.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_150.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_151.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_152.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_153.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_154.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_155.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_156.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_157.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_158.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_159.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_160.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_161.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_162.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_163.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_164.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_165.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_166.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_167.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_168.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_169.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_170.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_171.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_172.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_173.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_174.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_175.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_176.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_177.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_178.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_179.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_180.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_181.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_182.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_183.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_184.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_185.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_186.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_187.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_188.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_189.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_190.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_191.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_192.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_193.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_194.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_195.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_196.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_197.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_198.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_199.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_200.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_201.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_202.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_203.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_204.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_205.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_206.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_207.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_208.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_209.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_210.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_211.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_212.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_213.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_214.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_215.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_216.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_217.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_218.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_219.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_220.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_221.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_222.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_223.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_224.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_225.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_226.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_227.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_228.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_229.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_230.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_231.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_232.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_233.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_234.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_235.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_236.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_237.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_238.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_239.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_240.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_241.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_242.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_243.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_244.pkl
