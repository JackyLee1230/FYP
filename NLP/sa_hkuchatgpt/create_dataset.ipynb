# %% [markdown]
# Prompt engineering 27-09-2023 ver
#
# Extract a subset of data from large dataset.

# %%
import pandas as pd
import numpy as np

from pathlib import Path
import random

random.seed(13)
# take 15% for both testing and training from original. Then among that 15%, 70% for training, 30% for testing.

# NOTICE: change the dataset path to where your dataset.csv is.
dataset_path = Path('../fyp-workspace/dataset.csv').resolve()

# dataset = pd.read_csv(dataset_path, skiprows=lambda i: i > 0 and random.random() > p)
# dataset.head()

dataset = pd.read_csv(dataset_path)
dataset
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\uset\Documents\MyDocs\HKU\COMP4801\FYP\NLP\sa_hkuchatgpt\create_dataset.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/uset/Documents/MyDocs/HKU/COMP4801/FYP/NLP/sa_hkuchatgpt/create_dataset.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> dataset_path = Path('../fyp-workspace/dataset.csv')
#      <a href='vscode-notebook-cell:/c%3A/Users/uset/Documents/MyDocs/HKU/COMP4801/FYP/NLP/sa_hkuchatgpt/create_dataset.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a> # dataset = pd.read_csv(dataset_path, skiprows=lambda i: i > 0 and random.random() > p)
#      <a href='vscode-notebook-cell:/c%3A/Users/uset/Documents/MyDocs/HKU/COMP4801/FYP/NLP/sa_hkuchatgpt/create_dataset.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a> # dataset.head()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/uset/Documents/MyDocs/HKU/COMP4801/FYP/NLP/sa_hkuchatgpt/create_dataset.ipynb#W1sZmlsZQ%3D%3D?line=16'>17</a> dataset = pd.read_csv(dataset_path)
#      <a href='vscode-notebook-cell:/c%3A/Users/uset/Documents/MyDocs/HKU/COMP4801/FYP/NLP/sa_hkuchatgpt/create_dataset.ipynb#W1sZmlsZQ%3D%3D?line=17'>18</a> dataset
#
# File c:\Users\uset\Anaconda3\envs\hkuchatgpt\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\uset\Anaconda3\envs\hkuchatgpt\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\uset\Anaconda3\envs\hkuchatgpt\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\uset\Anaconda3\envs\hkuchatgpt\lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\uset\Anaconda3\envs\hkuchatgpt\lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\fyp-workspace\\dataset.csv'

# %%
# notice there are some null values
dataset.isnull().sum()
# Out:
# app_id               0
# app_name        183234
# review_text       7305
# review_score         0
# review_votes         0
# dtype: int64

# %%
# We remove rows that contains null values (for both column app_name and review_text)
dataset = dataset[dataset['app_name'].isnull() == False]

dataset = dataset[dataset['review_text'].isnull() == False]

dataset.isnull().sum()
# Out:
# app_id          0
# app_name        0
# review_text     0
# review_score    0
# review_votes    0
# dtype: int64

# %%
# convert columns to string type

dataset['review_text'] = dataset['review_text'].apply(str, 1)
dataset['app_name'] = dataset['app_name'].apply(str, 1)
dataset.head(10)
# Out:
# /var/folders/hm/n8540hpn7xd1f0pw3_qnsp4r0000gn/T/ipykernel_51600/1148837174.py:3: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   dataset['review_text'] = dataset['review_text'].apply(str, 1)
# /var/folders/hm/n8540hpn7xd1f0pw3_qnsp4r0000gn/T/ipykernel_51600/1148837174.py:4: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   dataset['app_name'] = dataset['app_name'].apply(str, 1)
#    app_id        app_name                                        review_text  \
# 0      10  Counter-Strike                                    Ruined my life.
# 1      10  Counter-Strike  This will be more of a ''my experience with th...
# 2      10  Counter-Strike                      This game saved my virginity.
# 3      10  Counter-Strike  • Do you like original games? • Do you like ga...
# 4      10  Counter-Strike           Easy to learn, hard to master.
# 5      10  Counter-Strike             No r8 revolver, 10/10 will play again.
# 6      10  Counter-Strike          Still better than Call of Duty: Ghosts...
# 7      10  Counter-Strike  cant buy skins, cases, keys, stickers - gaben ...
# 8      10  Counter-Strike  Counter-Strike: Ok, after 9 years of unlimited...
# 9      10  Counter-Strike  Every server is spanish or french. I can now f...
#
#    review_score  review_votes
# 0             1             0
# 1             1             1
# 2             1             0
# 3             1             0
# 4             1             1
# 5             1             1
# 6             1             1
# 7             1             1
# 8             1             1
# 9             1             0

# %%
# we notice that there are some rows onlu contain "Early Access Review" -> not helpful to the analysis
# we remove these rows.

print("before removing:", dataset.shape)

dataset = dataset[dataset['review_text'].str.contains("Early Access Review") == False]

print("after removing:", dataset.shape)
# Out:
# before removing: (6226728, 5)
# after removing: (5238690, 5)

# %% [markdown]
# There are 988038 rows that contain only "Early Access Review", which is not helpful to the analysis

# %%
# remove comments that contain ♥ (means foul language)

dataset_noheart = dataset[dataset['review_text'].str.contains('♥') == False]
print(dataset_noheart.shape)
print(dataset.shape)
# Out:
# (4891928, 5)
# (5238690, 5)

# %%
# sample randomly for rows
dataset_sampled = dataset_noheart.sample(frac=p, random_state=13)       # keep the same random_state to create the same rows 

dataset_sampled
# Out:
#          app_id                                  app_name  \
# 4994864  383870                                 Firewatch
# 4540004  348250                           Google Earth VR
# 1656212   22610                       Alien Breed: Impact
# 2841416  252950                             Rocket League
# 4922442  379720                                      DOOM
# ...         ...                                       ...
# 931947   212070                             Star Conflict
# 2209901  239160                                     Thief
# 2222841  239820                           Game Dev Tycoon
# 5910051  506610  Five Nights at Freddy's: Sister Location
# 6072015     570                                    Dota 2
#
#                                                review_text  review_score  \
# 4994864  Honestly, I sat here for a few minutes to ques...             1
# 4540004  Words can not describe how awesome experience ...             1
# 1656212  is fun to play if you know others who woulod p...             1
# 2841416  Took away all my items after not playing for 2...            -1
# 4922442  I can play this with a really bad CPU (A10-580...             1
# ...                                                    ...           ...
# 931947                     Skrim in S P ace. Rift support.             1
# 2209901  There once was a time when I liked this game. ...            -1
# 2222841  This is one of my all time favorite games. I p...             1
# 5910051  This game is amazing!! The only glitch I exper...             1
# 6072015                             10/10 - Ruined my life             1
#
#          review_votes
# 4994864             0
# 4540004             0
# 1656212             0
# 2841416             0
# 4922442             0
# ...               ...
# 931947              0
# 2209901             0
# 2222841             0
# 5910051             0
# 6072015             0
#
# [733789 rows x 5 columns]

# %%
# reset index particularly for creating dataset
dataset_sampled.reset_index(inplace=True)
dataset_sampled = dataset_sampled.rename(columns={'index': 'dataset_index'})
dataset_sampled = dataset_sampled.sort_values(by=['dataset_index'])
dataset_sampled.reset_index(inplace=True, drop=True)

dataset_sampled
# Out:
#         dataset_index  app_id        app_name  \
# 0                   0      10  Counter-Strike
# 1                   7      10  Counter-Strike
# 2                  10      10  Counter-Strike
# 3                  17      10  Counter-Strike
# 4                  46      10  Counter-Strike
# ...               ...     ...             ...
# 733784        6417083   99910  Puzzle Pirates
# 733785        6417089   99910  Puzzle Pirates
# 733786        6417098   99910  Puzzle Pirates
# 733787        6417100   99910  Puzzle Pirates
# 733788        6417101   99910  Puzzle Pirates
#
#                                               review_text  review_score  \
# 0                                         Ruined my life.             1
# 1       cant buy skins, cases, keys, stickers - gaben ...             1
# 2                         Fire in the Hole Simulator 1999             1
# 3       When you crouch, you lift your feet in the air...             1
# 4       With only ~4000 hours of playtime (plus a few ...             1
# ...                                                   ...           ...
# 733784                                 really boring game            -1
# 733785  Rating based on current state of play, as per ...            -1
# 733786  This game is good but also horrible. Its fun t...            -1
# 733787  This game is good but also horrible. Its fun t...            -1
# 733788  I really ove this game but it needs somethings...            -1
#
#         review_votes
# 0                  0
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 733784             0
# 733785             0
# 733786             0
# 733787             0
# 733788             0
#
# [733789 rows x 6 columns]

# %%
# save the modified dataset as pickle
# import datetime


# filename = f'dataset_cleaned_heartless_sampled_{datetime.datetime.now().strftime("%Y%m%d")}.pkl'
# save_path = Path(filename).resolve()
# dataset_sampled.to_pickle(save_path)
# print(f"Saved to: {save_path}")
# Out:
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless_sampled_20230927.pkl

# %% [markdown]
# ### Optional
#
# Saving the cleaned, heartless dataset to csv and pickle.

# %%
# optional

# save the cleaned dataset
dataset_noheart_tosave = dataset_noheart.reset_index()


filename = 'dataset_cleaned_heartless.csv'
save_path = Path(filename).resolve()
dataset_noheart_tosave.to_csv(save_path)

print(f"Saved to: {save_path}")
# Out:
# Saved to: dataset_cleaned_heartless.csv

# %%
filename_pkl = 'dataset_cleaned_heartless.pkl'
save_path_pkl = Path(filename_pkl).resolve()
dataset_noheart_tosave.to_pickle(save_path_pkl)

print(f"Saved to: {save_path_pkl}")
# Out:
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/hkuchatgpt_bot/dataset_cleaned_heartless.pkl

# %% [markdown]
# ------

# %%
# here we find the pickle files with processed ChatGPT rows

from pathlib import Path
import pandas as pd

processed_f_rpaths = [
    "dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_joincleanedchunks_20231009.pkl",
    "dataset_cleaned_heartless_sampled_20231028/dataset_cleaned_heartless_sampled_20231028_joincleanedchunks_20231129.pkl"
]

processed_df = []

for rpath in processed_f_rpaths:
    processed_df.append(
        pd.read_pickle(Path(rpath).resolve())
    )

dataset_processed = pd.concat(processed_df).reset_index(drop=True)

# %%
dataset_processed
# Out:
#        dataset_index  app_id                           app_name  \
# 0             949538  212680             FTL: Faster Than Light
# 1             417579   19680             Alice: Madness Returns
# 2            2140029  238460                BattleBlock Theater
# 3             491994  201810         Wolfenstein: The New Order
# 4            3303632  272010      Aveyond 3-1: Lord of Twilight
# ...              ...     ...                                ...
# 13525        3379127  275850                       No Man's Sky
# 13526        2894780  253710                  theHunter Classic
# 13527        4007720  311340  METAL GEAR SOLID V: GROUND ZEROES
# 13528        1316956  220260             Farming Simulator 2013
# 13529        5091293  391270                        Fingerbones
#
#                                              review_text  review_score  \
# 0      Amazing Game! Great Gameplay, and Great Re-pla...             1
# 1      This game is fantastic!  It is both fun to pla...             1
# 2      Dripping with fun, oozing with style, practica...             1
# 3      Great story-driven game - one of the better st...             1
# 4      Haven't played much of it yet but it seems lik...            -1
# ...                                                  ...           ...
# 13525                     I bought this game now im sad.            -1
# 13526  The worst kind of Free to Play I've ever seen....            -1
# 13527  They took the prologue of the Phantom pain, re...            -1
# 13528                             i wished it would work            -1
# 13529  This game was free, and I still want a refund,...            -1
#
#        review_votes                                           response  \
# 0                 0  {\n  "positive": 1.0,\n  "neutral": 0.0,\n  "n...
# 1                 0  {\n  "positive": 1.0,\n  "neutral": 0.0,\n  "n...
# 2                 0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 3                 0  {"positive": 1.0, "neutral": 0.0, "negative": ...
# 4                 0  {"positive": 0.0, "neutral": 0.0, "negative": ...
# ...             ...                                                ...
# 13525             1       {"positive": 0, "neutral": 0, "negative": 1}
# 13526             0  {"positive": 0.0, "neutral": 0.0, "negative": ...
# 13527             1  {"positive": 0.1, "neutral": 0.4, "negative": ...
# 13528             0  {"positive": 0.0, "neutral": 0.5, "negative": ...
# 13529             1    {"positive":0.0, "neutral":0.0, "negative":1.0}
#
#        total_token_used
# 0                   150
# 1                   195
# 2                   155
# 3                   149
# 4                   260
# ...                 ...
# 13525               119
# 13526               201
# 13527               412
# 13528               126
# 13529               393
#
# [13530 rows x 8 columns]

# %%
# distribution of positive and negative comments (original)

print('Positive commnents:', len(dataset_processed[(dataset_processed['review_score'] == 1)]))
print('Negative commnents:', len(dataset_processed[(dataset_processed['review_score'] == -1)]))
# Out:
# Positive commnents: 5950
# Negative commnents: 7580

# %% [markdown]
# Creating portions of dataset, with 3000 rows per dataset

# %%
import pandas as pd
from pathlib import Path
import random

dataset_cleaned_path = Path("../dev-workspace/dataset/sa/dataset_cleaned_heartless.pkl")
dataset_cleaned = pd.read_pickle(dataset_cleaned_path)

dataset_cleaned
# Out:
#            index  app_id        app_name  \
# 0              0      10  Counter-Strike
# 1              1      10  Counter-Strike
# 2              2      10  Counter-Strike
# 3              3      10  Counter-Strike
# 4              4      10  Counter-Strike
# ...          ...     ...             ...
# 4891923  6417101   99910  Puzzle Pirates
# 4891924  6417102   99910  Puzzle Pirates
# 4891925  6417103   99910  Puzzle Pirates
# 4891926  6417104   99910  Puzzle Pirates
# 4891927  6417105   99910  Puzzle Pirates
#
#                                                review_text  review_score  \
# 0                                          Ruined my life.             1
# 1        This will be more of a ''my experience with th...             1
# 2                            This game saved my virginity.             1
# 3        • Do you like original games? • Do you like ga...             1
# 4                 Easy to learn, hard to master.                       1
# ...                                                    ...           ...
# 4891923  I really ove this game but it needs somethings...            -1
# 4891924  Used to play Puzzel Pirates 'way back when', b...            -1
# 4891925  This game was aright, though a bit annoying. W...            -1
# 4891926  I had a nice review to recommend this game, bu...            -1
# 4891927  The puzzles in this game are fun, but you have...            -1
#
#          review_votes
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   1
# ...               ...
# 4891923             0
# 4891924             0
# 4891925             0
# 4891926             0
# 4891927             0
#
# [4891928 rows x 6 columns]

# %%
# we drop rows with the index existing in the processed datasets
dataset_cleaned_unprocessed = dataset_cleaned[
    ~dataset_cleaned['index'].isin(dataset_processed['dataset_index'])
]

dataset_cleaned_unprocessed
# Out:
#            index  app_id        app_name  \
# 0              0      10  Counter-Strike
# 1              1      10  Counter-Strike
# 2              2      10  Counter-Strike
# 3              3      10  Counter-Strike
# 4              4      10  Counter-Strike
# ...          ...     ...             ...
# 4891923  6417101   99910  Puzzle Pirates
# 4891924  6417102   99910  Puzzle Pirates
# 4891925  6417103   99910  Puzzle Pirates
# 4891926  6417104   99910  Puzzle Pirates
# 4891927  6417105   99910  Puzzle Pirates
#
#                                                review_text  review_score  \
# 0                                          Ruined my life.             1
# 1        This will be more of a ''my experience with th...             1
# 2                            This game saved my virginity.             1
# 3        • Do you like original games? • Do you like ga...             1
# 4                 Easy to learn, hard to master.                       1
# ...                                                    ...           ...
# 4891923  I really ove this game but it needs somethings...            -1
# 4891924  Used to play Puzzel Pirates 'way back when', b...            -1
# 4891925  This game was aright, though a bit annoying. W...            -1
# 4891926  I had a nice review to recommend this game, bu...            -1
# 4891927  The puzzles in this game are fun, but you have...            -1
#
#          review_votes
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   1
# ...               ...
# 4891923             0
# 4891924             0
# 4891925             0
# 4891926             0
# 4891927             0
#
# [4878398 rows x 6 columns]

# %%
# optional (only negative comments)
# dataset_cleaned_unprocessed = dataset_cleaned_unprocessed[dataset_cleaned_unprocessed['review_score'] == -1]

# len(dataset_cleaned_unprocessed)
# Out:
# 779885

# %%
# we shift them in random order.

dataset_cleaned_suffled = dataset_cleaned_unprocessed.sample(frac=1, random_state=42)   # add random_state for reproducability
dataset_cleaned_suffled
# Out:
#            index  app_id                          app_name  \
# 3578009  4753211  364360              Total War: WARHAMMER
# 1417392  1779512  230190             War for the Overworld
# 4768597  6281593    8000          Tomb Raider: Anniversary
# 3354944  4438017  340460       Spartans Vs Zombies Defense
# 895169   1051934  216150                        MapleStory
# ...          ...     ...                               ...
# 1846268  2300084  241930  Middle-earth™: Shadow of Mordor™
# 2518729  3298407  271590                Grand Theft Auto V
# 936815   1098709  218620                          PAYDAY 2
# 4104612  5420433     420          Half-Life 2: Episode Two
# 912199   1070585  218230                      PlanetSide 2
#
#                                                review_text  review_score  \
# 3578009  Bought the base game at 25% off sale. No DLCs....            -1
# 1417392  it's a fun game, and a really good follow-up f...            -1
# 4768597  6/10  Horrible PC Port  Clipping/glitching/fal...            -1
# 3354944                     In endless mode is very stupid            -1
# 895169   MapleStory is that one game you're probably ne...            -1
# ...                                                    ...           ...
# 1846268  Gameplay is super boring, mindless attack butt...            -1
# 2518729  s h i t game dont get it it doesnt deserve the...            -1
# 936815   The game is updating all the time, so it can't...            -1
# 4104612  Cliffhanger ending no episode 3 or HL 3.  Unti...            -1
# 912199            Great Optimization 10/10 would LAG again            -1
#
#          review_votes
# 3578009             1
# 1417392             0
# 4768597             0
# 3354944             0
# 895169              1
# ...               ...
# 1846268             1
# 2518729             0
# 936815              0
# 4104612             1
# 912199              0
#
# [779885 rows x 6 columns]

# %%
chunk_size = 3000

def slice_dataframe(df, chunk_size, N=-1):
    '''Creating smaller chunks of dataframes. Remaining rows will be put in the last chunk
    
    params:
    df: the large dataframe
    chunk_size: number of rows in each smaller chunk
    N: number of chunks to be created'''
    num_rows = len(df)
    num_chunks = num_rows // chunk_size
    remaining_rows = num_rows // chunk_size


    if 0 < N and N < num_chunks + 1:
        # valid value
        # create only specific number of chunks
        # drop remaining rows
        
        for i in range(N):
            start = i * chunk_size
            end = min((i + 1) * chunk_size, num_rows)
            yield df[start:end]

    else:
        # create a total of (num_chunks + 1) chunks

        # create num_chunks chunks
        for i in range(num_chunks):
            start = i * chunk_size
            end = min((i + 1) * chunk_size, num_rows)
            yield df[start:end]

        # last chunk, size of last chunk will be <= chunk_size
        if remaining_rows > 0:
            yield df[num_chunks * chunk_size:]

# sliced_dfs = [df for df in slice_dataframe(dataset_cleaned_suffled, chunk_size)]
sliced_dfs = [df for df in slice_dataframe(dataset_cleaned_suffled, chunk_size, 3)]

# reset index (for HKU ChatGPT)
sliced_dfs = list(map(lambda df: df.reset_index(drop=True), sliced_dfs))

# %%
len(sliced_dfs)
# Out:
# 3

# %%
sliced_dfs[1]
# Out:
#         index  app_id                           app_name  \
# 0      994303  214420                            Gear Up
# 1     5921434  513000                             Kuboom
# 2     1586410   22380                 Fallout: New Vegas
# 3     1769573  228880  Ashes of the Singularity: Classic
# 4      416823    1930           Two Worlds: Epic Edition
# ...       ...     ...                                ...
# 2995  4586933  351800                            Dev Guy
# 2996  4038944  313010                         Cities XXL
# 2997  3240464  270850        Car Mechanic Simulator 2014
# 2998  5998291     550                      Left 4 Dead 2
# 2999  4545201   34870             Sniper Ghost Warrior 2
#
#                                             review_text  review_score  \
# 0     Matchmaking is bad you get put with people way...            -1
# 1     A pay-to-win piece of trash. Did I just waste ...            -1
# 2     I love this game, but it's so full of bugs you...            -1
# 3     This game is either to easy or to hard, no cha...            -1
# 4          If you have Skyrim dont waste your time here            -1
# ...                                                 ...           ...
# 2995                this game isnt fun or entertaining.            -1
# 2996  This 'game' is the advertising campaign that P...            -1
# 2997  Terrible game , not worth 1$ , extreemly borin...            -1
# 2998                           Fun to play with friends            -1
# 2999  Worst fricking game of all time, DO NOT BUY, S...            -1
#
#       review_votes
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 2995             1
# 2996             0
# 2997             0
# 2998             0
# 2999             0
#
# [3000 rows x 6 columns]

# %%
from datetime import datetime


chunk_folder = Path(dataset_cleaned_path.stem + '_sampled_' + datetime.now().strftime("%Y%m%d") + '/')

if not chunk_folder.exists():
    chunk_folder.mkdir()

for i, sliced_df in enumerate(sliced_dfs):
    filename = f'{chunk_folder.stem}_chunk_{i:03}.pkl'
    save_path = chunk_folder.joinpath(filename).resolve()
    sliced_df.to_pickle(save_path)
    print(f"Saved to: {save_path}")
# Out:
# Saved to: C:\Users\uset\Documents\MyDocs\HKU\COMP4801\FYP\NLP\sa_hkuchatgpt\dataset_cleaned_heartless_sampled_20231028\dataset_cleaned_heartless_sampled_20231028_chunk_000.pkl
# Saved to: C:\Users\uset\Documents\MyDocs\HKU\COMP4801\FYP\NLP\sa_hkuchatgpt\dataset_cleaned_heartless_sampled_20231028\dataset_cleaned_heartless_sampled_20231028_chunk_001.pkl
# Saved to: C:\Users\uset\Documents\MyDocs\HKU\COMP4801\FYP\NLP\sa_hkuchatgpt\dataset_cleaned_heartless_sampled_20231028\dataset_cleaned_heartless_sampled_20231028_chunk_002.pkl

# %% [markdown]
# ---

# %% [markdown]
# 29/11/2023 update

# %%
# preprocessing

dataset_cleaned_unprocessed['num_of_words'] = dataset_cleaned_unprocessed['review_text'].apply(lambda x:len(str(x).split()))
dataset_cleaned_unprocessed = dataset_cleaned_unprocessed[dataset_cleaned_unprocessed['num_of_words'] > 0]

# at least 10 characters to be more meaningful :D
# or 5 words ??
dataset_cleaned_unprocessed = dataset_cleaned_unprocessed[dataset_cleaned_unprocessed['review_text'].str.len()>=10]

# %%
dataset_cleaned_unprocessed.head(10)
# Out:
#    index  app_id        app_name  \
# 0      0      10  Counter-Strike
# 1      1      10  Counter-Strike
# 2      2      10  Counter-Strike
# 3      3      10  Counter-Strike
# 4      4      10  Counter-Strike
# 5      5      10  Counter-Strike
# 6      6      10  Counter-Strike
# 7      7      10  Counter-Strike
# 8      8      10  Counter-Strike
# 9      9      10  Counter-Strike
#
#                                          review_text  review_score  \
# 0                                    Ruined my life.             1
# 1  This will be more of a ''my experience with th...             1
# 2                      This game saved my virginity.             1
# 3  • Do you like original games? • Do you like ga...             1
# 4           Easy to learn, hard to master.                       1
# 5             No r8 revolver, 10/10 will play again.             1
# 6          Still better than Call of Duty: Ghosts...             1
# 7  cant buy skins, cases, keys, stickers - gaben ...             1
# 8  Counter-Strike: Ok, after 9 years of unlimited...             1
# 9  Every server is spanish or french. I can now f...             1
#
#    review_votes  num_of_words
# 0             0             3
# 1             1           449
# 2             0             5
# 3             0            47
# 4             1             6
# 5             1             7
# 6             1             7
# 7             1            16
# 8             1           174
# 9             0            15

# %%
dataset_cleaned_unprocessed
# Out:
#            index  app_id        app_name  \
# 0              0      10  Counter-Strike
# 1              1      10  Counter-Strike
# 2              2      10  Counter-Strike
# 3              3      10  Counter-Strike
# 4              4      10  Counter-Strike
# ...          ...     ...             ...
# 4891923  6417101   99910  Puzzle Pirates
# 4891924  6417102   99910  Puzzle Pirates
# 4891925  6417103   99910  Puzzle Pirates
# 4891926  6417104   99910  Puzzle Pirates
# 4891927  6417105   99910  Puzzle Pirates
#
#                                                review_text  review_score  \
# 0                                          Ruined my life.             1
# 1        This will be more of a ''my experience with th...             1
# 2                            This game saved my virginity.             1
# 3        • Do you like original games? • Do you like ga...             1
# 4                 Easy to learn, hard to master.                       1
# ...                                                    ...           ...
# 4891923  I really ove this game but it needs somethings...            -1
# 4891924  Used to play Puzzel Pirates 'way back when', b...            -1
# 4891925  This game was aright, though a bit annoying. W...            -1
# 4891926  I had a nice review to recommend this game, bu...            -1
# 4891927  The puzzles in this game are fun, but you have...            -1
#
#          review_votes  num_of_words
# 0                   0             3
# 1                   1           449
# 2                   0             5
# 3                   0            47
# 4                   1             6
# ...               ...           ...
# 4891923             0           104
# 4891924             0            86
# 4891925             0            57
# 4891926             0            62
# 4891927             0           101
#
# [4806896 rows x 7 columns]

# %%
dataset_cleaned_unprocessed.drop(columns=['num_of_words'], inplace=True)

dataset_cleaned_unprocessed
# Out:
#            index  app_id        app_name  \
# 0              0      10  Counter-Strike
# 1              1      10  Counter-Strike
# 2              2      10  Counter-Strike
# 3              3      10  Counter-Strike
# 4              4      10  Counter-Strike
# ...          ...     ...             ...
# 4891923  6417101   99910  Puzzle Pirates
# 4891924  6417102   99910  Puzzle Pirates
# 4891925  6417103   99910  Puzzle Pirates
# 4891926  6417104   99910  Puzzle Pirates
# 4891927  6417105   99910  Puzzle Pirates
#
#                                                review_text  review_score  \
# 0                                          Ruined my life.             1
# 1        This will be more of a ''my experience with th...             1
# 2                            This game saved my virginity.             1
# 3        • Do you like original games? • Do you like ga...             1
# 4                 Easy to learn, hard to master.                       1
# ...                                                    ...           ...
# 4891923  I really ove this game but it needs somethings...            -1
# 4891924  Used to play Puzzel Pirates 'way back when', b...            -1
# 4891925  This game was aright, though a bit annoying. W...            -1
# 4891926  I had a nice review to recommend this game, bu...            -1
# 4891927  The puzzles in this game are fun, but you have...            -1
#
#          review_votes
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   1
# ...               ...
# 4891923             0
# 4891924             0
# 4891925             0
# 4891926             0
# 4891927             0
#
# [4806896 rows x 6 columns]

# %%
# optional
# create 3000 * 3 datasets such that each sub dataset contains equal number of postiive and negative comments

dataset_cleaned_unprocessed_pos = dataset_cleaned_unprocessed[dataset_cleaned_unprocessed['review_score'] == 1]
dataset_cleaned_unprocessed_neg = dataset_cleaned_unprocessed[dataset_cleaned_unprocessed['review_score'] == -1]

# shuffle them

dataset_cleaned_unprocessed_pos = dataset_cleaned_unprocessed_pos.sample(frac=1, random_state=13)
dataset_cleaned_unprocessed_neg = dataset_cleaned_unprocessed_neg.sample(frac=1, random_state=42)

# %%
chunk_size = 3000 // 2

def slice_dataframe(df, chunk_size, N=-1):
    '''Creating smaller chunks of dataframes. Remaining rows will be put in the last chunk
    
    params:
    df: the large dataframe
    chunk_size: number of rows in each smaller chunk
    N: number of chunks to be created'''
    num_rows = len(df)
    num_chunks = num_rows // chunk_size
    remaining_rows = num_rows // chunk_size


    if 0 < N and N < num_chunks + 1:
        # valid value
        # create only specific number of chunks
        # drop remaining rows
        
        for i in range(N):
            start = i * chunk_size
            end = min((i + 1) * chunk_size, num_rows)
            yield df[start:end]

    else:
        # create a total of (num_chunks + 1) chunks

        # create num_chunks chunks
        for i in range(num_chunks):
            start = i * chunk_size
            end = min((i + 1) * chunk_size, num_rows)
            yield df[start:end]

        # last chunk, size of last chunk will be <= chunk_size
        if remaining_rows > 0:
            yield df[num_chunks * chunk_size:]

# sliced_dfs = [df for df in slice_dataframe(dataset_cleaned_suffled, chunk_size)]
sliced_dfs_pos = [df for df in slice_dataframe(dataset_cleaned_unprocessed_pos, chunk_size, 3)]

# reset index (for HKU ChatGPT)
sliced_dfs_pos = list(map(lambda df: df.reset_index(drop=True), sliced_dfs_pos))

# negative comments
sliced_dfs_neg = [df for df in slice_dataframe(dataset_cleaned_unprocessed_neg, chunk_size, 3)]

# reset index (for HKU ChatGPT)
sliced_dfs_neg = list(map(lambda df: df.reset_index(drop=True), sliced_dfs_neg))

# %%
len(sliced_dfs_neg)
# Out:
# 3

# %%
# join each of them in pos and neg

sliced_dfs = []

for df_pos, df_neg in zip(sliced_dfs_pos, sliced_dfs_neg):
    df = pd.concat([df_pos, df_neg]).sample(frac=1)
    df.rename(columns={'index': 'dataset_index'}, inplace=True)
    df.reset_index(drop=True, inplace=True)

    sliced_dfs.append(df)

# %%
sliced_dfs[0]
# Out:
#       dataset_index  app_id                         app_name  \
# 0           4121377  319510          Five Nights at Freddy's
# 1           1985382  234140                          Mad Max
# 2           3924843  306660     Ultimate General: Gettysburg
# 3           5008454   38410                        Fallout 2
# 4           5562984  438040                Shakes and Fidget
# ...             ...     ...                              ...
# 2995        6247807   71250               Sonic Adventure DX
# 2996        5189334  394230                       Battleborn
# 2997        3602969  291480                          Warface
# 2998        4536993  347670  Karate Master 2 Knock Down Blow
# 2999        2589585  248970                           Vector
#
#                                             review_text  review_score  \
# 0     Very fun game if you enjoy horror games. At fi...             1
# 1     What the game lacks in depth of story and clun...             1
# 2     No matter what strategy you choose it always s...            -1
# 3     'Fallout? I'll make my own Fallout, with black...             1
# 4     This is a fun little game, fun idea, but unfor...            -1
# ...                                                 ...           ...
# 2995  One word. UNPLAYABLE!! Were do I begin? At the...            -1
# 2996  I get so bored waiting for the Matchfinding Qu...            -1
# 2997  Would not launch. Reinstalled and would not la...            -1
# 2998  Fighting was cool but the rest of the game fel...            -1
# 2999  Since Vector is one of my first steam games, I...             1
#
#       review_votes
# 0                0
# 1                0
# 2                1
# 3                1
# 4                1
# ...            ...
# 2995             0
# 2996             0
# 2997             0
# 2998             0
# 2999             1
#
# [3000 rows x 6 columns]

# %%
from datetime import datetime


chunk_folder = Path(dataset_cleaned_path.stem + '_sampled_' + datetime.now().strftime("%Y%m%d") + '/')

if not chunk_folder.exists():
    chunk_folder.mkdir()

for i, sliced_df in enumerate(sliced_dfs):
    filename = f'{chunk_folder.stem}_chunk_{i:03}.pkl'
    save_path = chunk_folder.joinpath(filename).resolve()
    sliced_df.to_pickle(save_path)
    print(f"Saved to: {save_path}")
# Out:
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/FYP/NLP/sa_hkuchatgpt/dataset_cleaned_heartless_sampled_20231129/dataset_cleaned_heartless_sampled_20231129_chunk_000.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/FYP/NLP/sa_hkuchatgpt/dataset_cleaned_heartless_sampled_20231129/dataset_cleaned_heartless_sampled_20231129_chunk_001.pkl
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/FYP/NLP/sa_hkuchatgpt/dataset_cleaned_heartless_sampled_20231129/dataset_cleaned_heartless_sampled_20231129_chunk_002.pkl
