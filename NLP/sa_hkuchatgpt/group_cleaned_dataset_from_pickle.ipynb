# %%
# temporary script to group pickles into a single file

# created on: 09-10-2023

from pathlib import Path
import os

import pandas as pd

dataset_folder = Path('dataset_cleaned_heartless_sampled_20230927').resolve()

for root, dirs, files in os.walk(dataset_folder):
    target_pkls = list(map(lambda f: Path(root, f), files))
    target_pkls = [p for p in target_pkls if p.suffix == '.pkl' and p.stem.find('cleaned_20231009') != -1]

    break   # only one-level

print(target_pkls)
# Out:
# [PosixPath('/Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/FYP/NLP/sa_hkuchatgpt/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_002_cleaned_20231009.pkl'), PosixPath('/Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/FYP/NLP/sa_hkuchatgpt/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_000_cleaned_20231009.pkl'), PosixPath('/Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/FYP/NLP/sa_hkuchatgpt/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_chunk_001_cleaned_20231009.pkl')]

# %%
# join them and save a new pickle



df = pd.concat([pd.read_pickle(p) for p in target_pkls])
    
df
# Out:
#       dataset_index  app_id                       app_name  \
# 0            949538  212680         FTL: Faster Than Light
# 1            417579   19680         Alice: Madness Returns
# 2           2140029  238460            BattleBlock Theater
# 3            491994  201810     Wolfenstein: The New Order
# 4           3303632  272010  Aveyond 3-1: Lord of Twilight
# ...             ...     ...                            ...
# 2301        2063861  236510            Takedown: Red Sabre
# 2302        2006210  234650              Shadowrun Returns
# 2303         390720   17450            Dragon Age: Origins
# 2304        4646351  357340                         Cobalt
# 2305        2873925  252950                  Rocket League
#
#                                             review_text  review_score  \
# 0     Amazing Game! Great Gameplay, and Great Re-pla...             1
# 1     This game is fantastic!  It is both fun to pla...             1
# ...

# %%
df.reset_index(inplace=True, drop=True)

df
# Out:
#       dataset_index  app_id                       app_name  \
# 0            949538  212680         FTL: Faster Than Light
# 1            417579   19680         Alice: Madness Returns
# 2           2140029  238460            BattleBlock Theater
# 3            491994  201810     Wolfenstein: The New Order
# 4           3303632  272010  Aveyond 3-1: Lord of Twilight
# ...             ...     ...                            ...
# 7033        2063861  236510            Takedown: Red Sabre
# 7034        2006210  234650              Shadowrun Returns
# 7035         390720   17450            Dragon Age: Origins
# 7036        4646351  357340                         Cobalt
# 7037        2873925  252950                  Rocket League
#
#                                             review_text  review_score  \
# 0     Amazing Game! Great Gameplay, and Great Re-pla...             1
# 1     This game is fantastic!  It is both fun to pla...             1
# ...

# %%
# save

from datetime import datetime


save_path = Path(dataset_folder, f'dataset_cleaned_heartless_sampled_20230927_joincleanedchunks_{datetime.now().strftime("%Y%m%d")}.pkl')

df.to_pickle(save_path)
print(f"Saved to: {save_path}")
# Out:
# Saved to: /Users/michaelcheng/Documents/MyDocs/HKU/COMP4801 FYP/FYP/NLP/sa_hkuchatgpt/dataset_cleaned_heartless_sampled_20230927/dataset_cleaned_heartless_sampled_20230927_joincleanedchunks_20231009.pkl
